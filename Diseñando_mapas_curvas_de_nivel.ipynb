# %% [markdown]
# <a href="https://colab.research.google.com/github/quvp861205/machinelearning/blob/master/Dise%C3%B1ando_mapas_curvas_de_nivel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dependencias

# %%
from matplotlib import cm # Para manejar colores
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Gráfica en 3 dimensiones

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})


res = 100

X = np.linspace(-4, 4, res)
Y = np.linspace(-4, 4, res)

X, Y = np.meshgrid(X, Y)

Z = np.sin(X) + 2*np.sin(Y) 

# Gráficar la superficie
surf = ax.plot_surface(X, Y, Z, cmap=cm.cool,
                       linewidth=0, antialiased=False)

fig.colorbar(surf)

# %% [markdown]
# ## Curvas de nivel

# %%
fig2,ax2 = plt.subplots()
level_map = np.linspace(np.min(Z), np.max(Z),res) 
cp = ax2.contourf(X, Y, Z, levels=level_map,cmap=cm.cool)
#cp = ax2.contour(X, Y, Z, levels=level_map,cmap=cm.cool)
fig2.colorbar(cp)
ax2.set_title('Curvas de nivel')
plt.show()
