# %%
# !pip  install --upgrade pandas
# !pip install --upgrade openpyxl
# !pip install --upgrade tables
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (3.6.1)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables) (2.7.3)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.7/dist-packages (from tables) (1.19.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/Colab Notebooks'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks
# '01 Dimension de escalar vector matriz o tensor.ipynb'
# '01 escalares vectores matrices tensores'
# '01 escalares vectores matrices tensores.ipynb'
# '02 Operaciones Basicas'
# '02 - Transposicion y Suma - matrices escalares.ipynb'
# '03 - Operaciones con Matrices'
# '03 - Suma de Matrices y Vectores (broadcasting).ipynb'
# '04 - Matrices identidad inversa singular'
# '05 - Sistemas de Ecuaciones Lineales'
# '06 - Normas'
# '07 - Matrices y Vectores especiales'
# '08 - Otras funciones'
# 'Algebra lineal aplicada a machine learning'
# 'Copia de 1 primeros pasos.ipynb'
# 'Copia de 2 dataframes.ipynb'
# 'Copia de 3 save and load.ipynb'
#  db
# 'Derivadas parciales para x,y,z.ipynb'
# 'Funcion de coste.ipynb'
#  funciones_auxiliares
# 'Fundamentos de algebra lineal.ipynb'
# 'Grafica con tendencia al limite.ipynb'
#  numpy.ipynb
# 'Obtener la derivada de una funcion.ipynb'
# 'Regresion linear.ipynb'
# 'uso de jupyter.ipynb'

# %%
'Hola {}'.format('bla bla bla bla')
# Out:
# 'Hola bla bla bla bla'

# %%
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/db
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/db’: File exists

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'.format('test.xls')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.xls'

# %%
import pandas as pd
print(pd.__version__)
import numpy as np
# Out:
# 1.3.4

# %%
dict_data = {
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9.0],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.csv'

# %%
df.to_csv(dir_pandas, index = False)

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks/db
# Out:
# API_AG.LND.AGRI.K2_DS2_en_csv_v2_716226.csv	Meteorite_Landings.csv
# API_AG.LND.FRST.K2_DS2_en_csv_v2_716262.csv	poblacion.csv
# API_EG.USE.ELEC.KH.PC_DS2_en_csv_v2_715482.csv	test.csv
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2_713263.csv	test.hdf
# API_SP.POP.TOTL_DS2_en_csv_v2_713131.csv	test.json
# covid_19_data.csv				test.parquet
# flights.db					test.pkl
# GlobalLandTemperaturesByCountry.csv		test.xlsx
# london_merged.csv

# %%
df_read = pd.read_csv('/content/drive/My Drive/Colab Notebooks/db/test.csv', sep = '|')
df_read
# Out:
#   edad,cm,pais,genero,Q1,Q2
# 0       10,115,co,M,5.0,7.0
# 1       9,110,mx,F,10.0,9.0
# 2       13,130,co,F,8.0,9.0
# 3          14,155,mx,M,,8.0
# 4       12,125,mx,M,7.0,8.0
# 5       11,120,ch,M,8.0,8.0
# 6       12,125,ch,F,3.0,9.0

# %%
df.to_csv(dir_pandas, sep = '|', index = False)

# %%
dir_pandas = '/content/drive/My Drive/Colab Notebooks/db/{}'
dir_pandas
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/{}'

# %%
df.to_excel(dir_pandas.format('test.xlsx'), index=False, sheet_name='Hoja_uno')

# %%
dir_pandas.format('test.xlsx')
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/test.xlsx'

# %%
pd.read_excel(dir_pandas.format('test.xlsx'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
df.to_json(dir_pandas.format('test.json'))

# %%
pd.read_json(dir_pandas.format('test.json'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_pickle(dir_pandas.format('test.pkl'))

# %%
pd.read_pickle(dir_pandas.format('test.pkl'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
df.to_parquet(dir_pandas.format('test.parquet'))

# %%
df.to_hdf(dir_pandas.format('test.hdf'),key='data',format='table')

# %%
pd.read_parquet(dir_pandas.format('test.parquet'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
pd.read_hdf(dir_pandas.format('test.hdf'))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0
