# %%
import numpy as np
import pandas as pd

# %%
print(pd.NA | False)
# Out:
# <NA>

# %%
df = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])


print(df['edad'] >= 12)
# Out:
# Ana         False
# Benito      False
# Camilo       True
# Daniel       True
# Erika        True
# Paola       False
# Gabriela     True
# Name: edad, dtype: bool

# %%
df = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])

print(df.iloc[[4],[2]])
# Out:
#       pais
# Erika   mx

# %%
df.describe()
# Out:
#             edad          cm         Q1        Q2
# count   7.000000    7.000000   6.000000  7.000000
# mean   11.571429  125.714286   6.833333  8.285714
# std     1.718249   14.556949   2.483277  0.755929
# min     9.000000  110.000000   3.000000  7.000000
# 25%    10.500000  117.500000   5.500000  8.000000
# 50%    12.000000  125.000000   7.500000  8.000000
# 75%    12.500000  127.500000   8.000000  9.000000
# max    14.000000  155.000000  10.000000  9.000000

# %%
np.array([10,8,5,0]) * np.array([0,1,6,12])
# Out:
# array([ 0,  8, 30,  0])

# %%
df.convert_dtypes()
# Out:
#           edad   cm pais genero    Q1  Q2
# Ana         10  115   co      F     5   7
# Benito       9  110   mx      M    10   9
# Camilo      13  130   co      M     8   9
# Daniel      14  155   mx      M  <NA>   8
# Erika       12  125   mx      F     7   8
# Paola       11  120   ch      F     8   8
# Gabriela    12  125   ch      F     3   9

# %%
list(df)
# Out:
# ['edad', 'cm', 'pais', 'genero', 'Q1', 'Q2']

# %%
df.set_index('pais','edad').sort_index()
# Out:
#       edad   cm genero    Q1   Q2
# pais
# ch      11  120      F   8.0  8.0
# ch      12  125      F   3.0  9.0
# co      10  115      F   5.0  7.0
# co      13  130      M   8.0  9.0
# mx       9  110      M  10.0  9.0
# mx      14  155      M   NaN  8.0
# mx      12  125      F   7.0  8.0

# %%
df.shape
# Out:
# (7, 6)

# %%
df = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])


print(df.loc[['Ana'],['cm']])
# Out:
#       cm
# Ana  115

# %%
df = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela']) 
df2 = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])

# %%
df.groupby(['genero'])['cm'].agg([np.mean, np.std])
# Out:
#               mean        std
# genero
# F       121.250000   4.787136
# M       131.666667  22.546249

# %%
df[['pais']].astype('category')
# Out:
#          pais
# Ana        co
# Benito     mx
# Camilo     co
# Daniel     mx
# Erika      mx
# Paola      ch
# Gabriela   ch

# %%
df.dtypes
# Out:
# edad        int64
# cm          int64
# pais       object
# genero     object
# Q1        float64
# Q2        float64
# dtype: object

# %%
df.dtypes
# Out:
# edad        int64
# cm          int64
# pais       object
# genero     object
# Q1        float64
# Q2        float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#              edad          cm pais genero         Q1        Q2
# count    7.000000    7.000000    7      7   6.000000  7.000000
# unique        NaN         NaN    3      2        NaN       NaN
# top           NaN         NaN   mx      F        NaN       NaN
# freq          NaN         NaN    3      4        NaN       NaN
# mean    11.571429  125.714286  NaN    NaN   6.833333  8.285714
# std      1.718249   14.556949  NaN    NaN   2.483277  0.755929
# min      9.000000  110.000000  NaN    NaN   3.000000  7.000000
# 25%     10.500000  117.500000  NaN    NaN   5.500000  8.000000
# 50%     12.000000  125.000000  NaN    NaN   7.500000  8.000000
# 75%     12.500000  127.500000  NaN    NaN   8.000000  9.000000
# max     14.000000  155.000000  NaN    NaN  10.000000  9.000000

# %%
df.append(df2)
# Out:
#           edad   cm pais genero    Q1   Q2
# Ana         10  115   co      F   5.0  7.0
# Benito       9  110   mx      M  10.0  9.0
# Camilo      13  130   co      M   8.0  9.0
# Daniel      14  155   mx      M   NaN  8.0
# Erika       12  125   mx      F   7.0  8.0
# Paola       11  120   ch      F   8.0  8.0
# Gabriela    12  125   ch      F   3.0  9.0
# Ana         10  115   co      F   5.0  7.0
# Benito       9  110   mx      M  10.0  9.0
# Camilo      13  130   co      M   8.0  9.0
# Daniel      14  155   mx      M   NaN  8.0
# Erika       12  125   mx      F   7.0  8.0
# Paola       11  120   ch      F   8.0  8.0
# Gabriela    12  125   ch      F   3.0  9.0

# %%
pd.concat([df,df2], ignore_index=True)
# Out:
#     edad   cm pais genero    Q1   Q2
# 0     10  115   co      F   5.0  7.0
# 1      9  110   mx      M  10.0  9.0
# 2     13  130   co      M   8.0  9.0
# 3     14  155   mx      M   NaN  8.0
# 4     12  125   mx      F   7.0  8.0
# 5     11  120   ch      F   8.0  8.0
# 6     12  125   ch      F   3.0  9.0
# 7     10  115   co      F   5.0  7.0
# 8      9  110   mx      M  10.0  9.0
# 9     13  130   co      M   8.0  9.0
# 10    14  155   mx      M   NaN  8.0
# 11    12  125   mx      F   7.0  8.0
# 12    11  120   ch      F   8.0  8.0
# 13    12  125   ch      F   3.0  9.0

# %%
df.merge(df2, on='cm')
# Out:
#    edad_x   cm pais_x genero_x  Q1_x  Q2_x  edad_y pais_y genero_y  Q1_y  Q2_y
# 0      10  115     co        F   5.0   7.0      10     co        F   5.0   7.0
# 1       9  110     mx        M  10.0   9.0       9     mx        M  10.0   9.0
# 2      13  130     co        M   8.0   9.0      13     co        M   8.0   9.0
# 3      14  155     mx        M   NaN   8.0      14     mx        M   NaN   8.0
# 4      12  125     mx        F   7.0   8.0      12     mx        F   7.0   8.0
# 5      12  125     mx        F   7.0   8.0      12     ch        F   3.0   9.0
# 6      12  125     ch        F   3.0   9.0      12     mx        F   7.0   8.0
# 7      12  125     ch        F   3.0   9.0      12     ch        F   3.0   9.0
# 8      11  120     ch        F   8.0   8.0      11     ch        F   8.0   8.0

# %%
pd.merge(df, df2, how='left', on='cm')
# Out:
#    edad_x   cm pais_x genero_x  Q1_x  Q2_x  edad_y pais_y genero_y  Q1_y  Q2_y
# 0      10  115     co        F   5.0   7.0      10     co        F   5.0   7.0
# 1       9  110     mx        M  10.0   9.0       9     mx        M  10.0   9.0
# 2      13  130     co        M   8.0   9.0      13     co        M   8.0   9.0
# 3      14  155     mx        M   NaN   8.0      14     mx        M   NaN   8.0
# 4      12  125     mx        F   7.0   8.0      12     mx        F   7.0   8.0
# 5      12  125     mx        F   7.0   8.0      12     ch        F   3.0   9.0
# 6      11  120     ch        F   8.0   8.0      11     ch        F   8.0   8.0
# 7      12  125     ch        F   3.0   9.0      12     mx        F   7.0   8.0
# 8      12  125     ch        F   3.0   9.0      12     ch        F   3.0   9.0

# %%
pd.Series([10,8,5,0]) - pd.Series([0,1,6,12])
# Out:
# 0    10
# 1     7
# 2    -1
# 3   -12
# dtype: int64

# %%
df_woman = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])

# %%
df_woman.query("genero=='F'")['edad'].mean()
# Out:
# 11.25

# %%
df_x = pd.DataFrame({
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'F', 'M', 'M', 'M', 'F', 'F', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}, index = ['Ana','Benito','Camilo','Daniel','Erika','Paola','Gabriela'])


print(df_x.query("(edad >= 12) & (cm < 130) & (Q1 > 5)")['Q2'])
# Out:
# Erika    8.0
# Name: Q2, dtype: float64

# %%
[10,8,5,0] + [0,1,6,12]
# Out:
# [10, 8, 5, 0, 0, 1, 6, 12]

# %%
df_x.drop(columns=['edad'])
# Out:
#            cm pais genero    Q1   Q2
# Ana       115   co      F   5.0  7.0
# Benito    110   mx      M  10.0  9.0
# Camilo    130   co      M   8.0  9.0
# Daniel    155   mx      M   NaN  8.0
# Erika     125   mx      F   7.0  8.0
# Paola     120   ch      F   8.0  8.0
# Gabriela  125   ch      F   3.0  9.0
