# %% [markdown]
# # Clasificación de palabras (por género de nombre)

# %%
import nltk, random
nltk.download('names')
from nltk.corpus import names
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %% [markdown]
# **Función básica de extracción de atributos**

# %%
# definición de atributos relevantes
def atributos(palabra):
	return {'ultima_letra': palabra[-1]}

tagset = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

# %%
tagset[:10]
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male')]

# %%
random.shuffle(tagset)
tagset[:10]
# Out:
# [('Gisella', 'female'),
#  ('Darius', 'male'),
#  ('Skippy', 'male'),
#  ('Odelia', 'female'),
#  ('Irvin', 'male'),
#  ('Nathanil', 'male'),
#  ('Briggs', 'male'),
#  ('Vite', 'male'),
#  ('Binny', 'female'),
#  ('Harcourt', 'male')]

# %%
fset = [(atributos(n), g) for (n, g) in tagset]
train, test = fset[500:], fset[:500]

# %% [markdown]
# **Modelo de clasificación Naive Bayes**

# %%
# entrenamiento del modelo NaiveBayes
classifier = nltk.NaiveBayesClassifier.train(train)

# %% [markdown]
#  **Verificación de algunas predicciones**

# %%
classifier.classify(atributos('amanda'))
# Out:
# 'female'

# %%
classifier.classify(atributos('peter'))
# Out:
# 'male'

# %% [markdown]
# **Performance del modelo**

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.734

# %%
print(nltk.classify.accuracy(classifier, train))
# Out:
# 0.7647770016120365

# %% [markdown]
# **Mejores atributos**

# %%
def mas_atributos(nombre):
    atrib = {}
    atrib["primera_letra"] = nombre[0].lower()
    atrib["ultima_letra"] = nombre[-1].lower()
    for letra in 'abcdefghijklmnopqrstuvwxyz':
        atrib["count({})".format(letra)] = nombre.lower().count(letra)
        atrib["has({})".format(letra)] = (letra in nombre.lower())
    return atrib

# %%
mas_atributos('rodrigo')
# Out:
# {'count(a)': 0,
#  'count(b)': 0,
#  'count(c)': 0,
#  'count(d)': 1,
#  'count(e)': 0,
#  'count(f)': 0,
#  'count(g)': 1,
#  'count(h)': 0,
#  'count(i)': 1,
#  'count(j)': 0,
#  'count(k)': 0,
#  'count(l)': 0,
#  'count(m)': 0,
#  'count(n)': 0,
#  'count(o)': 2,
#  'count(p)': 0,
#  'count(q)': 0,
#  'count(r)': 2,
#  'count(s)': 0,
#  'count(t)': 0,
#  'count(u)': 0,
#  'count(v)': 0,
#  'count(w)': 0,
#  'count(x)': 0,
#  'count(y)': 0,
#  'count(z)': 0,
#  'has(a)': False,
#  'has(b)': False,
#  'has(c)': False,
#  'has(d)': True,
#  'has(e)': False,
#  'has(f)': False,
#  'has(g)': True,
#  'has(h)': False,
#  'has(i)': True,
#  'has(j)': False,
#  'has(k)': False,
#  'has(l)': False,
#  'has(m)': False,
#  'has(n)': False,
#  'has(o)': True,
#  'has(p)': False,
#  'has(q)': False,
#  'has(r)': True,
#  'has(s)': False,
#  'has(t)': False,
#  'has(u)': False,
#  'has(v)': False,
#  'has(w)': False,
#  'has(x)': False,
#  'has(y)': False,
#  'has(z)': False,
#  'primera_letra': 'r',
#  'ultima_letra': 'o'}

# %%
fset = [(mas_atributos(n), g) for (n, g) in tagset]
train, test = fset[500:], fset[:500]
classifier2 = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier2, test))
print(nltk.classify.accuracy(classifier2, train))
# Out:
# 0.766
# 0.7787479849543256

# %% [markdown]
# ### Ejercicio de práctica
#
# **Objetivo:** Construye un classificador de nombres en español usando el siguiente dataset:
# https://github.com/jvalhondo/spanish-names-surnames

# %% [markdown]
# 1. **Preparación de los datos**: con un `git clone` puedes traer el dataset indicado a tu directorio en Colab, luego asegurate de darle el formato adecuado a los datos y sus features para que tenga la misma estructura del ejemplo anterior con el dataset `names` de nombres en ingles.
#
# * **Piensa y analiza**: ¿los features en ingles aplican de la misma manera para los nombres en español?

# %%
# escribe tu código aquí

# %% [markdown]
# 2. **Entrenamiento y performance del modelo**: usando el classificador de Naive Bayes de NLTK entrena un modelo sencillo usando el mismo feature de la última letra del nombre, prueba algunas predicciones y calcula el performance del modelo.

# %%
# escribe tu código aquí

# %% [markdown]
# 3. **Mejores atributos:** Define una función como `atributos2()` donde puedas extraer mejores atributos con los cuales entrenar una mejor version del clasificador. Haz un segundo entrenamiento y verifica como mejora el performance de tu modelo. ¿Se te ocurren mejores maneras de definir atributos para esta tarea particular?

# %%
# escribe tu código aquí

# %% [markdown]
# # Clasificación de documentos (email spam o no spam)

# %%
# !git clone https://github.com/pachocamacho1990/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.

# %%
import pandas as pd
import numpy as np
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df = pd.read_csv('datasets/email/csv/spam-apache.csv', names = ['clase','contenido'])
df['tokens'] = df['contenido'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#    clase  ...                                             tokens
# 0     -1  ...  [<, !, DOCTYPE, HTML, PUBLIC, ``, -//W3C//DTD,...
# 1      1  ...  [>, Russell, Turpin, :, >, >, That, depends, o...
# 2     -1  ...  [Help, wanted, ., We, are, a, 14, year, old, f...
# 3     -1  ...  [Request, A, Free, No, Obligation, Consultatio...
# 4      1  ...  [Is, there, a, way, to, look, for, a, particul...
#
# [5 rows x 3 columns]

# %%
df['tokens'].values[0]

# %%
all_words = nltk.FreqDist([w for tokenlist in df['tokens'].values for w in tokenlist])
top_words = all_words.most_common(200)

def document_features(document):
    document_words = set(document)
    features = {}
    for word in top_words:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
document_features(df['tokens'].values[0])

# %%
fset = [(document_features(texto), clase) for texto, clase in zip(df['tokens'].values, df['clase'].values)]
random.shuffle(fset)
train, test = fset[:200], fset[200:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.48

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#     contains(('us', 53)) = False               1 : -1     =      1.0 : 1.0
#  contains(('could', 66)) = False               1 : -1     =      1.0 : 1.0
#  contains(('money', 72)) = False               1 : -1     =      1.0 : 1.0
#   contains(('days', 40)) = False               1 : -1     =      1.0 : 1.0
#   contains(('need', 43)) = False               1 : -1     =      1.0 : 1.0

# %%
df[df['clase']==-1]['contenido']
# Out:
# 0      <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# 2      Help wanted.  We are a 14 year old fortune 500...
# 3      Request A Free No Obligation Consultation!\nAc...
# 10     >\n>“µ×è¹µÑÇ ¡ÑºâÅ¡¸ØÃ¡Ô¨º¹ÍÔ¹àµÍÃìà¹çµ” \n>àµ...
# 11     ==============================================...
#                              ...
# 243    ##############################################...
# 244    Wanna see sexually curious teens playing with ...
# 246    REQUEST FOR URGENT BUSINESS ASSISTANCE\n------...
# 248    Email marketing works!  There's no way around ...
# 249    Email marketing works!  There's no way around ...
# Name: contenido, Length: 125, dtype: object

# %% [markdown]
# ## Ejercicio de práctica

# %% [markdown]
# ¿Como podrías construir un mejor clasificador de documentos?
#
# 0. **Dataset más grande:** El conjunto de datos que usamos fue muy pequeño, considera usar los archivos corpus que estan ubicados en la ruta: `datasets/email/plaintext/`
#
# 1. **Limpieza:** como te diste cuenta no hicimos ningun tipo de limpieza de texto en los correos electrónicos. Considera usar expresiones regulares, filtros por categorias gramaticales, etc ... .
#
# ---
#
# Con base en eso construye un dataset más grande y con un tokenizado más pulido.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# escribe tu código aquí:

# %% [markdown]
# 2. **Validación del modelo anterior:**
# ---
#
# una vez tengas el nuevo conjunto de datos más pulido y de mayor tamaño, considera el mismo entrenamiento con el mismo tipo de atributos del ejemplo anterior, ¿mejora el accuracy del modelo resultante?

# %%
# escribe tu código aquí:

# %% [markdown]
# 3. **Construye mejores atributos**: A veces no solo se trata de las palabras más frecuentes sino de el contexto, y capturar contexto no es posible solo viendo los tokens de forma individual, ¿que tal si consideramos bi-gramas, tri-gramas ...?, ¿las secuencias de palabras podrián funcionar como mejores atributos para el modelo?. Para ver si es así,  podemos extraer n-gramas de nuestro corpus y obtener sus frecuencias de aparición con `FreqDist()`, desarrolla tu propia manera de hacerlo y entrena un modelo con esos nuevos atributos, no olvides compartir tus resultados en la sección de comentarios.

# %%
# escribe tu código aquí:

# %% [markdown]
# # Se cambian los features para dar mejor precision en la prediccion de clasificacion

# %%
import os
import nltk
import random
from nltk import word_tokenize
from nltk.collocations import *
import pandas as pd
nltk.download("punkt")

# !git clone https://github.com/pachocamacho1990/datasets
! unzip datasets/email/plaintext/corpus1.zip
! unzip datasets/email/plaintext/corpus2.zip
! unzip datasets/email/plaintext/corpus3.zip

#Funciones para cargar los datasets

# Get Text and labels from folders with plain text files
def get_text_labels_from_folders(folderBase, folderLabels):
  data = []
  labels = []

  for folderLabel in folderLabels:
    for file in os.listdir('{}/{}'.format(folderBase, folderLabel)):
      with open('{}/{}/{}'.format(folderBase, folderLabel, file), encoding='latin-1') as f:
        data.append(f.read())
        labels.append(folderLabel)

  return data, labels

def set_label_num(label_str):
  if label_str == "spam":
      return 1
  else:
      return 0
 
dataCorpus1, labelsCorpus1 = get_text_labels_from_folders('corpus1', ["spam", "ham"])
dataCorpus2, labelsCorpus2 = get_text_labels_from_folders('corpus2', ["spam", "ham"])
dataCorpus3, labelsCorpus3 = get_text_labels_from_folders('corpus3', ["spam", "ham"])
data = dataCorpus1 + dataCorpus2 + dataCorpus3
labels = labelsCorpus1 + labelsCorpus2 + labelsCorpus3

dataframe = pd.DataFrame({'text': data, 'labels': labels})
dataframe = dataframe.sample(frac = 1) 
dataframe['tokens'] = dataframe['text'].apply(lambda x: word_tokenize(x))
dataframe['labels_num'] = dataframe['labels'].apply(lambda x: set_label_num(x))

#Funciones para filtrar palabras y obtener colocaciones de n gramas

def filter_words_by_threshold(text_tokenized, threshold = 3, ):
  words = []
  words = [word for word in text_tokenized if len(word) > threshold]
  return words

def get_n_grams_collocations_from_words(words, freq_filter = 10, n_best= 10,
                                       n_gran_measure = nltk.collocations.BigramAssocMeasures()):
  finder = BigramCollocationFinder.from_words(words)
  finder.apply_freq_filter(freq_filter)
  email_spam_collocations = finder.nbest(n_gran_measure.pmi, n_best)
  return email_spam_collocations

#Obtener las colocaciones y palabras más comunes en el datasets de spam

spamCorpus1, _ = get_text_labels_from_folders('corpus1', ["spam"])
spamCorpus2, _ = get_text_labels_from_folders('corpus2', ["spam"])
spamCorpus3, _ = get_text_labels_from_folders('corpus3', ["spam"])
spamCorpuses = spamCorpus1 + spamCorpus2 + spamCorpus3

filtered_words = []
for text in spamCorpuses:
  filtered_words += filter_words_by_threshold(word_tokenize(text))
filtered_words

email_spam_collocations = get_n_grams_collocations_from_words(filtered_words, 120, 40)
all_spam_words = nltk.FreqDist([w for w in filtered_words])
top_spam_words = all_spam_words.most_common(200)

#Obtener las colocaciones y palabras comunes en el datasets de ham

hamCorpus1, _ = get_text_labels_from_folders('corpus1', ["ham"])
hamCorpus2, _ = get_text_labels_from_folders('corpus2', ["ham"])
hamCorpus3, _ = get_text_labels_from_folders('corpus3', ["ham"])
hamCorpuses = hamCorpus1 + hamCorpus2 + hamCorpus3

filtered_words = []
for text in hamCorpuses:
  filtered_words += filter_words_by_threshold(word_tokenize(text))
filtered_words

email_ham_collocations = get_n_grams_collocations_from_words(filtered_words, 120, 40)
all_ham_words = nltk.FreqDist([w for w in filtered_words])
top_ham_words = all_ham_words.most_common(200)

#Filtrar palabras repetidas de palabras más comunes en spam y ham.

top_ham_words_iterator = top_ham_words
for word in top_ham_words_iterator:
  if word in top_ham_words and word in top_spam_words: 
    top_ham_words.remove(word)
    top_spam_words.remove(word)

#Obtener palabras más comunes de todo el dataset

filtered_words = []
for text in data:
  filtered_words += filter_words_by_threshold(word_tokenize(text))
filtered_words
all_words = nltk.FreqDist([w for w in filtered_words])
top_words = all_words.most_common(200)
top_words

#Obtener los atributos

def document_attributes(document):
  document_words = set(document)
  atrib = {}
  for word in top_words:
    atrib['contains({})'.format(word)] = (word in document_words)
  
  for word in top_spam_words:
    atrib['contains_spam_word({})'.format(word)] = (word in document_words)

  for word in top_ham_words:
    atrib['contains_ham_word({})'.format(word)] = (word in document_words)

  
  for word in document_words:
    has_spam_word = False
    has_ham_word = False

    for bigram_position_0, bigram_position_1 in email_spam_collocations:
        if word == bigram_position_0 or word == bigram_position_1:
          has_spam_word = True
          break

    for bigram_position_0, bigram_position_1 in email_ham_collocations:
        if word == bigram_position_0 or word == bigram_position_1:
          has_ham_word = True
          break

      
    atrib['spam_word({})'.format(word)] = has_spam_word
    atrib['ham_word({})'.format(word)] = has_ham_word
    
    
  filtered_words = filter_words_by_threshold(document)
  bigrams = get_n_grams_collocations_from_words(filtered_words, n_best=10, freq_filter=5)

  for i in range(len(bigrams)):
    atrib['bigram_collocation({})'.format(i)] = bigrams[i]
    
  return atrib

#Separar dataset de prueba y entrenamiento

fset = [(document_attributes(text), labels) for text, labels in zip(dataframe['tokens'], dataframe['labels_num'].values)]
random.shuffle(fset)
print(len(fset))
train, test = fset[:13078], fset[13078:]

#Entrenar y calcular accuracy

classifier = nltk.NaiveBayesClassifier.train(train)
print(nltk.classify.accuracy(classifier, test))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: corpus3/spam/2275.2004-12-22.BG.spam.txt
#   inflating: corpus3/spam/0687.2004-09-19.BG.spam.txt
#   inflating: corpus3/spam/1151.2004-10-21.BG.spam.txt
#   inflating: corpus3/spam/4203.2005-04-02.BG.spam.txt
#   inflating: corpus3/spam/4263.2005-04-06.BG.spam.txt
#   inflating: corpus3/spam/4731.2005-05-07.BG.spam.txt
#   inflating: corpus3/spam/3005.2005-01-25.BG.spam.txt
#   inflating: corpus3/spam/4744.2005-05-08.BG.spam.txt
#   inflating: corpus3/spam/1371.2004-11-02.BG.spam.txt
#   inflating: corpus3/spam/3408.2005-02-12.BG.spam.txt
#   inflating: corpus3/spam/4523.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/2991.2005-01-24.BG.spam.txt
#   inflating: corpus3/spam/4529.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/1376.2004-11-02.BG.spam.txt
#   inflating: corpus3/spam/2971.2005-01-23.BG.spam.txt
#   inflating: corpus3/spam/0767.2004-09-24.BG.spam.txt
#   inflating: corpus3/spam/1617.2004-11-15.BG.spam.txt
#   inflating: corpus3/spam/5234.2005-06-11.BG.spam.txt
#   inflating: corpus3/spam/3481.2005-02-17.BG.spam.txt
#   inflating: corpus3/spam/1152.2004-10-21.BG.spam.txt
#   inflating: corpus3/spam/1860.2004-11-28.BG.spam.txt
#   inflating: corpus3/spam/5151.2005-06-06.BG.spam.txt
#   inflating: corpus3/spam/1251.2004-10-26.BG.spam.txt
#   inflating: corpus3/spam/2782.2005-01-17.BG.spam.txt
#   inflating: corpus3/spam/3648.2005-02-25.BG.spam.txt
#   inflating: corpus3/spam/5589.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/0971.2004-10-08.BG.spam.txt
#   inflating: corpus3/spam/1275.2004-10-27.BG.spam.txt
#   inflating: corpus3/spam/5450.2005-06-27.BG.spam.txt
#   inflating: corpus3/spam/5863.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/1504.2004-11-09.BG.spam.txt
#   inflating: corpus3/spam/3961.2005-03-17.BG.spam.txt
#   inflating: corpus3/spam/1125.2004-10-19.BG.spam.txt
#   inflating: corpus3/spam/3385.2005-02-11.BG.spam.txt
#   inflating: corpus3/spam/5227.2005-06-10.BG.spam.txt
#   inflating: corpus3/spam/2369.2004-12-27.BG.spam.txt
#   inflating: corpus3/spam/5604.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/0760.2004-09-24.BG.spam.txt
#   inflating: corpus3/spam/5154.2005-06-06.BG.spam.txt
#   inflating: corpus3/spam/4779.2005-05-11.BG.spam.txt
#   inflating: corpus3/spam/5610.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/3039.2005-01-26.BG.spam.txt
#   inflating: corpus3/spam/2256.2004-12-21.BG.spam.txt
#   inflating: corpus3/spam/0065.2004-08-05.BG.spam.txt
#   inflating: corpus3/spam/3218.2005-02-04.BG.spam.txt
#   inflating: corpus3/spam/4742.2005-05-08.BG.spam.txt
#   inflating: corpus3/spam/1511.2004-11-09.BG.spam.txt
#   inflating: corpus3/spam/1037.2004-10-13.BG.spam.txt
#   inflating: corpus3/spam/1166.2004-10-22.BG.spam.txt
#   inflating: corpus3/spam/3475.2005-02-16.BG.spam.txt
#   inflating: corpus3/spam/3222.2005-02-04.BG.spam.txt
#   inflating: corpus3/spam/1458.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/5575.2005-07-05.BG.spam.txt
#   inflating: corpus3/spam/3817.2005-03-08.BG.spam.txt
#   inflating: corpus3/spam/2434.2004-12-30.BG.spam.txt
#   inflating: corpus3/spam/3373.2005-02-10.BG.spam.txt
#   inflating: corpus3/spam/0768.2004-09-24.BG.spam.txt
#   inflating: corpus3/spam/4621.2005-05-01.BG.spam.txt
#   inflating: corpus3/spam/1746.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/3423.2005-02-14.BG.spam.txt
#   inflating: corpus3/spam/0692.2004-09-20.BG.spam.txt
#   inflating: corpus3/spam/2359.2004-12-26.BG.spam.txt
#   inflating: corpus3/spam/1919.2004-12-01.BG.spam.txt
#   inflating: corpus3/spam/0806.2004-09-27.BG.spam.txt
#   inflating: corpus3/spam/0695.2004-09-20.BG.spam.txt
#   inflating: corpus3/spam/4071.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/3085.2005-01-29.BG.spam.txt
#   inflating: corpus3/spam/2084.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/1247.2004-10-26.BG.spam.txt
#   inflating: corpus3/spam/2156.2004-12-17.BG.spam.txt
#   inflating: corpus3/spam/2938.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/5719.2005-07-13.BG.spam.txt
#   inflating: corpus3/spam/3528.2005-02-19.BG.spam.txt
#   inflating: corpus3/spam/2941.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/2523.2005-01-04.BG.spam.txt
#   inflating: corpus3/spam/1330.2004-10-30.BG.spam.txt
#   inflating: corpus3/spam/5026.2005-05-27.BG.spam.txt
#   inflating: corpus3/spam/1707.2004-11-19.BG.spam.txt
#   inflating: corpus3/spam/0195.2004-08-14.BG.spam.txt
#   inflating: corpus3/spam/2148.2004-12-16.BG.spam.txt
#   inflating: corpus3/spam/3692.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/5536.2005-07-02.BG.spam.txt
#   inflating: corpus3/spam/1871.2004-11-29.BG.spam.txt
#   inflating: corpus3/spam/3668.2005-02-27.BG.spam.txt
#   inflating: corpus3/spam/5360.2005-06-20.BG.spam.txt
#   inflating: corpus3/spam/1800.2004-11-24.BG.spam.txt
#   inflating: corpus3/spam/2163.2004-12-17.BG.spam.txt
#   inflating: corpus3/spam/3626.2005-02-23.BG.spam.txt
#   inflating: corpus3/spam/0309.2004-08-23.BG.spam.txt
#   inflating: corpus3/spam/4391.2005-04-14.BG.spam.txt
#   inflating: corpus3/spam/2708.2005-01-14.BG.spam.txt
#   inflating: corpus3/spam/2655.2005-01-11.BG.spam.txt
#   inflating: corpus3/spam/4210.2005-04-03.BG.spam.txt
#   inflating: corpus3/spam/3050.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/5979.2005-07-29.BG.spam.txt
#   inflating: corpus3/spam/2694.2005-01-13.BG.spam.txt
#   inflating: corpus3/spam/0144.2004-08-11.BG.spam.txt
#   inflating: corpus3/spam/0783.2004-09-26.BG.spam.txt
#   inflating: corpus3/spam/5698.2005-07-11.BG.spam.txt
#   inflating: corpus3/spam/2149.2004-12-16.BG.spam.txt
#   inflating: corpus3/spam/2231.2004-12-20.BG.spam.txt
#   inflating: corpus3/spam/5945.2005-07-27.BG.spam.txt
#   inflating: corpus3/spam/2848.2005-01-20.BG.spam.txt
#   inflating: corpus3/spam/3053.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/3126.2005-01-31.BG.spam.txt
#   inflating: corpus3/spam/2112.2004-12-14.BG.spam.txt
#   inflating: corpus3/spam/2207.2004-12-19.BG.spam.txt
#   inflating: corpus3/spam/2078.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/0203.2004-08-15.BG.spam.txt
#   inflating: corpus3/spam/5177.2005-06-08.BG.spam.txt
#   inflating: corpus3/spam/4352.2005-04-11.BG.spam.txt
#   inflating: corpus3/spam/4289.2005-04-08.BG.spam.txt
#   inflating: corpus3/spam/4489.2005-04-21.BG.spam.txt
#   inflating: corpus3/spam/5521.2005-07-01.BG.spam.txt
#   inflating: corpus3/spam/3064.2005-01-28.BG.spam.txt
#   inflating: corpus3/spam/1826.2004-11-26.BG.spam.txt
#   inflating: corpus3/spam/1973.2004-12-05.BG.spam.txt
#   inflating: corpus3/spam/5207.2005-06-09.BG.spam.txt
#   inflating: corpus3/spam/0520.2004-09-08.BG.spam.txt
#   inflating: corpus3/spam/2011.2004-12-08.BG.spam.txt
#   inflating: corpus3/spam/4114.2005-03-26.BG.spam.txt
#   inflating: corpus3/spam/2710.2005-01-14.BG.spam.txt
#   inflating: corpus3/spam/3991.2005-03-19.BG.spam.txt
#   inflating: corpus3/spam/0675.2004-09-18.BG.spam.txt
#   inflating: corpus3/spam/1261.2004-10-27.BG.spam.txt
#   inflating: corpus3/spam/3748.2005-03-04.BG.spam.txt
#   inflating: corpus3/spam/5474.2005-06-28.BG.spam.txt
#   inflating: corpus3/spam/3047.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/4340.2005-04-10.BG.spam.txt
#   inflating: corpus3/spam/2581.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/0436.2004-09-02.BG.spam.txt
#   inflating: corpus3/spam/4666.2005-05-04.BG.spam.txt
#   inflating: corpus3/spam/1211.2004-10-24.BG.spam.txt
#   inflating: corpus3/spam/3168.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/2812.2005-01-18.BG.spam.txt
#   inflating: corpus3/spam/2353.2004-12-26.BG.spam.txt
#   inflating: corpus3/spam/4189.2005-04-01.BG.spam.txt
#   inflating: corpus3/spam/3416.2005-02-13.BG.spam.txt
#   inflating: corpus3/spam/4075.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/1594.2004-11-13.BG.spam.txt
#   inflating: corpus3/spam/5105.2005-06-02.BG.spam.txt
#   inflating: corpus3/spam/4336.2005-04-10.BG.spam.txt
#   inflating: corpus3/spam/2989.2005-01-24.BG.spam.txt
#   inflating: corpus3/spam/4243.2005-04-05.BG.spam.txt
#   inflating: corpus3/spam/3942.2005-03-16.BG.spam.txt
#   inflating: corpus3/spam/0810.2004-09-28.BG.spam.txt
#   inflating: corpus3/spam/3602.2005-02-21.BG.spam.txt
#   inflating: corpus3/spam/0848.2004-09-30.BG.spam.txt
#   inflating: corpus3/spam/1586.2004-11-12.BG.spam.txt
#   inflating: corpus3/spam/4816.2005-05-14.BG.spam.txt
#   inflating: corpus3/spam/2884.2005-01-21.BG.spam.txt
#   inflating: corpus3/spam/2955.2005-01-23.BG.spam.txt
#   inflating: corpus3/spam/2000.2004-12-08.BG.spam.txt
#   inflating: corpus3/spam/4450.2005-04-18.BG.spam.txt
#   inflating: corpus3/spam/2576.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/5412.2005-06-25.BG.spam.txt
#   inflating: corpus3/spam/5074.2005-05-31.BG.spam.txt
#   inflating: corpus3/spam/1742.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/0951.2004-10-07.BG.spam.txt
#   inflating: corpus3/spam/0813.2004-09-28.BG.spam.txt
#   inflating: corpus3/spam/5966.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/3142.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/3418.2005-02-13.BG.spam.txt
#   inflating: corpus3/spam/1722.2004-11-20.BG.spam.txt
#   inflating: corpus3/spam/2115.2004-12-14.BG.spam.txt
#   inflating: corpus3/spam/5784.2005-07-16.BG.spam.txt
#   inflating: corpus3/spam/2691.2005-01-13.BG.spam.txt
#   inflating: corpus3/spam/0778.2004-09-25.BG.spam.txt
#   inflating: corpus3/spam/3930.2005-03-15.BG.spam.txt
#   inflating: corpus3/spam/1101.2004-10-18.BG.spam.txt
#   inflating: corpus3/spam/2343.2004-12-25.BG.spam.txt
#   inflating: corpus3/spam/4768.2005-05-10.BG.spam.txt
#   inflating: corpus3/spam/0040.2004-08-03.BG.spam.txt
#   inflating: corpus3/spam/2395.2004-12-29.BG.spam.txt
#   inflating: corpus3/spam/1213.2004-10-24.BG.spam.txt
#   inflating: corpus3/spam/1540.2004-11-10.BG.spam.txt
#   inflating: corpus3/spam/1409.2004-11-04.BG.spam.txt
#   inflating: corpus3/spam/1256.2004-10-26.BG.spam.txt
#   inflating: corpus3/spam/0236.2004-08-18.BG.spam.txt
#   inflating: corpus3/spam/3151.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/0049.2004-08-04.BG.spam.txt
#   inflating: corpus3/spam/4381.2005-04-13.BG.spam.txt
#   inflating: corpus3/spam/3540.2005-02-19.BG.spam.txt
#   inflating: corpus3/spam/4968.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/2693.2005-01-13.BG.spam.txt
#   inflating: corpus3/spam/4558.2005-04-26.BG.spam.txt
#   inflating: corpus3/spam/2885.2005-01-21.BG.spam.txt
#   inflating: corpus3/spam/0851.2004-09-30.BG.spam.txt
#   inflating: corpus3/spam/5540.2005-07-02.BG.spam.txt
#   inflating: corpus3/spam/5872.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/0106.2004-08-08.BG.spam.txt
#   inflating: corpus3/spam/4846.2005-05-16.BG.spam.txt
#   inflating: corpus3/spam/1660.2004-11-18.BG.spam.txt
#   inflating: corpus3/spam/3378.2005-02-11.BG.spam.txt
#   inflating: corpus3/spam/3150.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/0789.2004-09-26.BG.spam.txt
#   inflating: corpus3/spam/4930.2005-05-21.BG.spam.txt
#   inflating: corpus3/spam/0761.2004-09-24.BG.spam.txt
#   inflating: corpus3/spam/1517.2004-11-09.BG.spam.txt
#   inflating: corpus3/spam/2814.2005-01-18.BG.spam.txt
#   inflating: corpus3/spam/4438.2005-04-18.BG.spam.txt
#   inflating: corpus3/spam/0179.2004-08-13.BG.spam.txt
#   inflating: corpus3/spam/4078.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/2064.2004-12-11.BG.spam.txt
#   inflating: corpus3/spam/3201.2005-02-03.BG.spam.txt
#   inflating: corpus3/spam/0700.2004-09-20.BG.spam.txt
#   inflating: corpus3/spam/4526.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/3359.2005-02-10.BG.spam.txt
#   inflating: corpus3/spam/2465.2005-01-02.BG.spam.txt
#   inflating: corpus3/spam/5454.2005-06-27.BG.spam.txt
#   inflating: corpus3/spam/0376.2004-08-28.BG.spam.txt
#   inflating: corpus3/spam/4483.2005-04-21.BG.spam.txt
#   inflating: corpus3/spam/3936.2005-03-16.BG.spam.txt
#   inflating: corpus3/spam/0171.2004-08-12.BG.spam.txt
#   inflating: corpus3/spam/2447.2004-12-31.BG.spam.txt
#   inflating: corpus3/spam/1561.2004-11-11.BG.spam.txt
#   inflating: corpus3/spam/1880.2004-11-29.BG.spam.txt
#   inflating: corpus3/spam/4288.2005-04-08.BG.spam.txt
#   inflating: corpus3/spam/4815.2005-05-14.BG.spam.txt
#   inflating: corpus3/spam/1340.2004-10-30.BG.spam.txt
#   inflating: corpus3/spam/0641.2004-09-17.BG.spam.txt
#   inflating: corpus3/spam/4882.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/4737.2005-05-08.BG.spam.txt
#   inflating: corpus3/spam/5435.2005-06-26.BG.spam.txt
#   inflating: corpus3/spam/4749.2005-05-09.BG.spam.txt
#   inflating: corpus3/spam/5032.2005-05-27.BG.spam.txt
#   inflating: corpus3/spam/2386.2004-12-28.BG.spam.txt
#   inflating: corpus3/spam/5335.2005-06-18.BG.spam.txt
#   inflating: corpus3/spam/0353.2004-08-27.BG.spam.txt
#   inflating: corpus3/spam/3337.2005-02-09.BG.spam.txt
#   inflating: corpus3/spam/0872.2004-10-02.BG.spam.txt
#   inflating: corpus3/spam/4518.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/5153.2005-06-06.BG.spam.txt
#   inflating: corpus3/spam/3680.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/5411.2005-06-24.BG.spam.txt
#   inflating: corpus3/spam/0752.2004-09-23.BG.spam.txt
#   inflating: corpus3/spam/3154.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/2574.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/5345.2005-06-19.BG.spam.txt
#   inflating: corpus3/spam/0656.2004-09-17.BG.spam.txt
#   inflating: corpus3/spam/3908.2005-03-14.BG.spam.txt
#   inflating: corpus3/spam/0506.2004-09-07.BG.spam.txt
#   inflating: corpus3/spam/1471.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/5272.2005-06-14.BG.spam.txt
#   inflating: corpus3/spam/4638.2005-05-02.BG.spam.txt
#   inflating: corpus3/spam/0295.2004-08-21.BG.spam.txt
#   inflating: corpus3/spam/5998.2005-07-30.BG.spam.txt
#   inflating: corpus3/spam/1346.2004-10-31.BG.spam.txt
#   inflating: corpus3/spam/0551.2004-09-11.BG.spam.txt
#   inflating: corpus3/spam/3794.2005-03-07.BG.spam.txt
#   inflating: corpus3/spam/0715.2004-09-21.BG.spam.txt
#   inflating: corpus3/spam/5301.2005-06-16.BG.spam.txt
#   inflating: corpus3/spam/0664.2004-09-18.BG.spam.txt
#   inflating: corpus3/spam/2260.2004-12-22.BG.spam.txt
#   inflating: corpus3/spam/0361.2004-08-27.BG.spam.txt
#   inflating: corpus3/spam/4539.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/2263.2004-12-22.BG.spam.txt
#   inflating: corpus3/spam/3857.2005-03-10.BG.spam.txt
#   inflating: corpus3/spam/4273.2005-04-07.BG.spam.txt
#   inflating: corpus3/spam/5535.2005-07-02.BG.spam.txt
#   inflating: corpus3/spam/4789.2005-05-12.BG.spam.txt
#   inflating: corpus3/spam/1242.2004-10-26.BG.spam.txt
#   inflating: corpus3/spam/3256.2005-02-05.BG.spam.txt
#   inflating: corpus3/spam/1352.2004-11-01.BG.spam.txt
#   inflating: corpus3/spam/3004.2005-01-25.BG.spam.txt
#   inflating: corpus3/spam/2724.2005-01-14.BG.spam.txt
#   inflating: corpus3/spam/4215.2005-04-03.BG.spam.txt
#   inflating: corpus3/spam/5944.2005-07-27.BG.spam.txt
#   inflating: corpus3/spam/5377.2005-06-21.BG.spam.txt
#   inflating: corpus3/spam/0553.2004-09-11.BG.spam.txt
#   inflating: corpus3/spam/5363.2005-06-20.BG.spam.txt
#   inflating: corpus3/spam/4169.2005-03-30.BG.spam.txt
#   inflating: corpus3/spam/4916.2005-05-20.BG.spam.txt
#   inflating: corpus3/spam/5629.2005-07-07.BG.spam.txt
#   inflating: corpus3/spam/5730.2005-07-14.BG.spam.txt
#   inflating: corpus3/spam/2773.2005-01-17.BG.spam.txt
#   inflating: corpus3/spam/2652.2005-01-11.BG.spam.txt
#   inflating: corpus3/spam/3970.2005-03-17.BG.spam.txt
#   inflating: corpus3/spam/4736.2005-05-08.BG.spam.txt
#   inflating: corpus3/spam/0319.2004-08-23.BG.spam.txt
#   inflating: corpus3/spam/2448.2004-12-31.BG.spam.txt
#   inflating: corpus3/spam/2288.2004-12-23.BG.spam.txt
#   inflating: corpus3/spam/1169.2004-10-22.BG.spam.txt
#   inflating: corpus3/spam/2086.2004-12-13.BG.spam.txt
#   inflating: corpus3/spam/3224.2005-02-04.BG.spam.txt
#   inflating: corpus3/spam/1390.2004-11-03.BG.spam.txt
#   inflating: corpus3/spam/0160.2004-08-11.BG.spam.txt
#   inflating: corpus3/spam/2180.2004-12-18.BG.spam.txt
#   inflating: corpus3/spam/4680.2005-05-05.BG.spam.txt
#   inflating: corpus3/spam/3862.2005-03-11.BG.spam.txt
#   inflating: corpus3/spam/0071.2004-08-05.BG.spam.txt
#   inflating: corpus3/spam/2220.2004-12-20.BG.spam.txt
#   inflating: corpus3/spam/3875.2005-03-12.BG.spam.txt
#   inflating: corpus3/spam/0803.2004-09-27.BG.spam.txt
#   inflating: corpus3/spam/0255.2004-08-19.BG.spam.txt
#   inflating: corpus3/spam/2154.2004-12-17.BG.spam.txt
#   inflating: corpus3/spam/0055.2004-08-04.BG.spam.txt
#   inflating: corpus3/spam/3329.2005-02-08.BG.spam.txt
#   inflating: corpus3/spam/3815.2005-03-08.BG.spam.txt
#   inflating: corpus3/spam/0307.2004-08-22.BG.spam.txt
#   inflating: corpus3/spam/3984.2005-03-18.BG.spam.txt
#   inflating: corpus3/spam/5815.2005-07-18.BG.spam.txt
#   inflating: corpus3/spam/5652.2005-07-09.BG.spam.txt
#   inflating: corpus3/spam/0304.2004-08-22.BG.spam.txt
#   inflating: corpus3/spam/0559.2004-09-11.BG.spam.txt
#   inflating: corpus3/spam/0185.2004-08-13.BG.spam.txt
#   inflating: corpus3/spam/2490.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/3057.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/0296.2004-08-21.BG.spam.txt
#  extracting: corpus3/spam/4927.2005-05-20.BG.spam.txt
#   inflating: corpus3/spam/2718.2005-01-14.BG.spam.txt
#   inflating: corpus3/spam/0776.2004-09-25.BG.spam.txt
#   inflating: corpus3/spam/5617.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/5675.2005-07-10.BG.spam.txt
#   inflating: corpus3/spam/2382.2004-12-28.BG.spam.txt
#   inflating: corpus3/spam/5788.2005-07-16.BG.spam.txt
#   inflating: corpus3/spam/1752.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/2232.2004-12-20.BG.spam.txt
#   inflating: corpus3/spam/5267.2005-06-14.BG.spam.txt
#   inflating: corpus3/spam/5968.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/2235.2004-12-20.BG.spam.txt
#   inflating: corpus3/spam/3647.2005-02-25.BG.spam.txt
#   inflating: corpus3/spam/1405.2004-11-04.BG.spam.txt
#   inflating: corpus3/spam/3352.2005-02-10.BG.spam.txt
#   inflating: corpus3/spam/1619.2004-11-15.BG.spam.txt
#   inflating: corpus3/spam/5490.2005-06-29.BG.spam.txt
#   inflating: corpus3/spam/4258.2005-04-06.BG.spam.txt
#   inflating: corpus3/spam/3675.2005-02-27.BG.spam.txt
#   inflating: corpus3/spam/2153.2004-12-17.BG.spam.txt
#   inflating: corpus3/spam/5243.2005-06-11.BG.spam.txt
#   inflating: corpus3/spam/1568.2004-11-12.BG.spam.txt
#   inflating: corpus3/spam/2120.2004-12-15.BG.spam.txt
#   inflating: corpus3/spam/3175.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/3687.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/4466.2005-04-19.BG.spam.txt
#   inflating: corpus3/spam/2089.2004-12-13.BG.spam.txt
#   inflating: corpus3/spam/3503.2005-02-18.BG.spam.txt
#   inflating: corpus3/spam/0503.2004-09-07.BG.spam.txt
#   inflating: corpus3/spam/5475.2005-06-28.BG.spam.txt
#   inflating: corpus3/spam/1276.2004-10-27.BG.spam.txt
#   inflating: corpus3/spam/1269.2004-10-27.BG.spam.txt
#   inflating: corpus3/spam/3838.2005-03-09.BG.spam.txt
#   inflating: corpus3/spam/4182.2005-03-31.BG.spam.txt
#   inflating: corpus3/spam/4729.2005-05-07.BG.spam.txt
#   inflating: corpus3/spam/4683.2005-05-05.BG.spam.txt
#   inflating: corpus3/spam/0593.2004-09-14.BG.spam.txt
#   inflating: corpus3/spam/0548.2004-09-10.BG.spam.txt
#   inflating: corpus3/spam/4101.2005-03-26.BG.spam.txt
#   inflating: corpus3/spam/1984.2004-12-06.BG.spam.txt
#   inflating: corpus3/spam/0430.2004-09-01.BG.spam.txt
#   inflating: corpus3/spam/0986.2004-10-09.BG.spam.txt
#   inflating: corpus3/spam/0095.2004-08-07.BG.spam.txt
#   inflating: corpus3/spam/3885.2005-03-13.BG.spam.txt
#   inflating: corpus3/spam/4879.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/0308.2004-08-22.BG.spam.txt
#   inflating: corpus3/spam/2211.2004-12-19.BG.spam.txt
#   inflating: corpus3/spam/0944.2004-10-06.BG.spam.txt
#   inflating: corpus3/spam/3954.2005-03-17.BG.spam.txt
#   inflating: corpus3/spam/0120.2004-08-10.BG.spam.txt
#   inflating: corpus3/spam/5315.2005-06-17.BG.spam.txt
#   inflating: corpus3/spam/4132.2005-03-28.BG.spam.txt
#   inflating: corpus3/spam/2101.2004-12-13.BG.spam.txt
#   inflating: corpus3/spam/3017.2005-01-25.BG.spam.txt
#   inflating: corpus3/spam/4591.2005-04-29.BG.spam.txt
#   inflating: corpus3/spam/2818.2005-01-19.BG.spam.txt
#   inflating: corpus3/spam/5822.2005-07-18.BG.spam.txt
#   inflating: corpus3/spam/2700.2005-01-13.BG.spam.txt
#   inflating: corpus3/spam/2138.2004-12-15.BG.spam.txt
#   inflating: corpus3/spam/4632.2005-05-01.BG.spam.txt
#   inflating: corpus3/spam/4797.2005-05-13.BG.spam.txt
#   inflating: corpus3/spam/2161.2004-12-17.BG.spam.txt
#   inflating: corpus3/spam/0240.2004-08-18.BG.spam.txt
#   inflating: corpus3/spam/5426.2005-06-26.BG.spam.txt
#   inflating: corpus3/spam/4958.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/4087.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/3995.2005-03-19.BG.spam.txt
#   inflating: corpus3/spam/3683.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/2591.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/0563.2004-09-12.BG.spam.txt
#   inflating: corpus3/spam/5219.2005-06-10.BG.spam.txt
#   inflating: corpus3/spam/0058.2004-08-04.BG.spam.txt
#   inflating: corpus3/spam/4408.2005-04-15.BG.spam.txt
#   inflating: corpus3/spam/4410.2005-04-16.BG.spam.txt
#   inflating: corpus3/spam/5518.2005-07-01.BG.spam.txt
#   inflating: corpus3/spam/4278.2005-04-07.BG.spam.txt
#   inflating: corpus3/spam/2079.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/5297.2005-06-16.BG.spam.txt
#   inflating: corpus3/spam/5857.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/2869.2005-01-20.BG.spam.txt
#   inflating: corpus3/spam/2735.2005-01-15.BG.spam.txt
#   inflating: corpus3/spam/4871.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/1134.2004-10-19.BG.spam.txt
#  extracting: corpus3/spam/0594.2004-09-14.BG.spam.txt
#   inflating: corpus3/spam/4695.2005-05-06.BG.spam.txt
#   inflating: corpus3/spam/4146.2005-03-28.BG.spam.txt
#   inflating: corpus3/spam/4848.2005-05-16.BG.spam.txt
#   inflating: corpus3/spam/4578.2005-04-28.BG.spam.txt
#   inflating: corpus3/spam/2041.2004-12-10.BG.spam.txt
#   inflating: corpus3/spam/1679.2004-11-18.BG.spam.txt
#   inflating: corpus3/spam/1460.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/1918.2004-12-01.BG.spam.txt
#   inflating: corpus3/spam/2564.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/0712.2004-09-21.BG.spam.txt
#   inflating: corpus3/spam/3684.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/5283.2005-06-15.BG.spam.txt
#   inflating: corpus3/spam/2687.2005-01-13.BG.spam.txt
#   inflating: corpus3/spam/3324.2005-02-08.BG.spam.txt
#   inflating: corpus3/spam/3985.2005-03-18.BG.spam.txt
#  extracting: corpus3/spam/1444.2004-11-06.BG.spam.txt
#   inflating: corpus3/spam/0921.2004-10-05.BG.spam.txt
#   inflating: corpus3/spam/0745.2004-09-23.BG.spam.txt
#   inflating: corpus3/spam/2974.2005-01-23.BG.spam.txt
#   inflating: corpus3/spam/0960.2004-10-08.BG.spam.txt
#   inflating: corpus3/spam/2474.2005-01-02.BG.spam.txt
#   inflating: corpus3/spam/3804.2005-03-07.BG.spam.txt
#   inflating: corpus3/spam/4032.2005-03-21.BG.spam.txt
#   inflating: corpus3/spam/4672.2005-05-04.BG.spam.txt
#   inflating: corpus3/spam/0348.2004-08-26.BG.spam.txt
#   inflating: corpus3/spam/5862.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/2927.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/5634.2005-07-07.BG.spam.txt
#   inflating: corpus3/spam/5955.2005-07-27.BG.spam.txt
#   inflating: corpus3/spam/3348.2005-02-09.BG.spam.txt
#   inflating: corpus3/spam/4367.2005-04-12.BG.spam.txt
#   inflating: corpus3/spam/3532.2005-02-19.BG.spam.txt
#   inflating: corpus3/spam/4393.2005-04-14.BG.spam.txt
#   inflating: corpus3/spam/2534.2005-01-05.BG.spam.txt
#   inflating: corpus3/spam/4971.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/0280.2004-08-20.BG.spam.txt
#   inflating: corpus3/spam/0909.2004-10-04.BG.spam.txt
#   inflating: corpus3/spam/3496.2005-02-17.BG.spam.txt
#   inflating: corpus3/spam/1686.2004-11-19.BG.spam.txt
#   inflating: corpus3/spam/2045.2004-12-11.BG.spam.txt
#   inflating: corpus3/spam/3037.2005-01-26.BG.spam.txt
#   inflating: corpus3/spam/4706.2005-05-06.BG.spam.txt
#   inflating: corpus3/spam/0332.2004-08-25.BG.spam.txt
#   inflating: corpus3/spam/2222.2004-12-20.BG.spam.txt
#  extracting: corpus3/spam/5910.2005-07-23.BG.spam.txt
#   inflating: corpus3/spam/5005.2005-05-26.BG.spam.txt
#   inflating: corpus3/spam/3059.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/2578.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/2566.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/1491.2004-11-08.BG.spam.txt
#   inflating: corpus3/spam/2901.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/3129.2005-01-31.BG.spam.txt
#   inflating: corpus3/spam/3380.2005-02-11.BG.spam.txt
#   inflating: corpus3/spam/1048.2004-10-14.BG.spam.txt
#   inflating: corpus3/spam/5770.2005-07-16.BG.spam.txt
#   inflating: corpus3/spam/4818.2005-05-14.BG.spam.txt
#   inflating: corpus3/spam/4262.2005-04-06.BG.spam.txt
#   inflating: corpus3/spam/5040.2005-05-28.BG.spam.txt
#   inflating: corpus3/spam/4891.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/3460.2005-02-15.BG.spam.txt
#   inflating: corpus3/spam/2559.2005-01-06.BG.spam.txt
#   inflating: corpus3/spam/3681.2005-02-28.BG.spam.txt
#   inflating: corpus3/spam/1988.2004-12-06.BG.spam.txt
#   inflating: corpus3/spam/3756.2005-03-04.BG.spam.txt
#   inflating: corpus3/spam/4970.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/4499.2005-04-22.BG.spam.txt
#   inflating: corpus3/spam/0577.2004-09-14.BG.spam.txt
#   inflating: corpus3/spam/5037.2005-05-28.BG.spam.txt
#   inflating: corpus3/spam/2438.2004-12-30.BG.spam.txt
#   inflating: corpus3/spam/0031.2004-08-03.BG.spam.txt
#   inflating: corpus3/spam/3361.2005-02-10.BG.spam.txt
#   inflating: corpus3/spam/2519.2005-01-04.BG.spam.txt
#   inflating: corpus3/spam/0897.2004-10-03.BG.spam.txt
#   inflating: corpus3/spam/0081.2004-08-06.BG.spam.txt
#   inflating: corpus3/spam/3195.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/3625.2005-02-23.BG.spam.txt
#   inflating: corpus3/spam/4196.2005-04-01.BG.spam.txt
#   inflating: corpus3/spam/5868.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/3091.2005-01-30.BG.spam.txt
#   inflating: corpus3/spam/2419.2004-12-30.BG.spam.txt
#   inflating: corpus3/spam/5870.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/1947.2004-12-03.BG.spam.txt
#   inflating: corpus3/spam/5993.2005-07-29.BG.spam.txt
#   inflating: corpus3/spam/1850.2004-11-27.BG.spam.txt
#   inflating: corpus3/spam/3767.2005-03-05.BG.spam.txt
#   inflating: corpus3/spam/1627.2004-11-16.BG.spam.txt
#  extracting: corpus3/spam/3157.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/5394.2005-06-23.BG.spam.txt
#   inflating: corpus3/spam/5034.2005-05-27.BG.spam.txt
#   inflating: corpus3/spam/5844.2005-07-19.BG.spam.txt
#   inflating: corpus3/spam/4233.2005-04-05.BG.spam.txt
#   inflating: corpus3/spam/1224.2004-10-25.BG.spam.txt
#   inflating: corpus3/spam/4366.2005-04-12.BG.spam.txt
#   inflating: corpus3/spam/2429.2004-12-30.BG.spam.txt
#   inflating: corpus3/spam/3275.2005-02-06.BG.spam.txt
#   inflating: corpus3/spam/2816.2005-01-19.BG.spam.txt
#   inflating: corpus3/spam/5307.2005-06-16.BG.spam.txt
#   inflating: corpus3/spam/4306.2005-04-09.BG.spam.txt
#   inflating: corpus3/spam/4599.2005-04-29.BG.spam.txt
#   inflating: corpus3/spam/2662.2005-01-11.BG.spam.txt
#   inflating: corpus3/spam/5041.2005-05-28.BG.spam.txt
#   inflating: corpus3/spam/3404.2005-02-12.BG.spam.txt
#   inflating: corpus3/spam/2915.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/5407.2005-06-24.BG.spam.txt
#   inflating: corpus3/spam/0498.2004-09-06.BG.spam.txt
#   inflating: corpus3/spam/0968.2004-10-08.BG.spam.txt
#   inflating: corpus3/spam/3565.2005-02-20.BG.spam.txt
#   inflating: corpus3/spam/5455.2005-06-27.BG.spam.txt
#   inflating: corpus3/spam/5257.2005-06-13.BG.spam.txt
#   inflating: corpus3/spam/3174.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/1043.2004-10-14.BG.spam.txt
#   inflating: corpus3/spam/0263.2004-08-19.BG.spam.txt
#   inflating: corpus3/spam/3926.2005-03-15.BG.spam.txt
#   inflating: corpus3/spam/2685.2005-01-12.BG.spam.txt
#   inflating: corpus3/spam/5839.2005-07-19.BG.spam.txt
#   inflating: corpus3/spam/4019.2005-03-20.BG.spam.txt
#   inflating: corpus3/spam/2070.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/1475.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/4574.2005-04-28.BG.spam.txt
#   inflating: corpus3/spam/3572.2005-02-20.BG.spam.txt
#   inflating: corpus3/spam/2183.2004-12-18.BG.spam.txt
#   inflating: corpus3/spam/1999.2004-12-08.BG.spam.txt
#   inflating: corpus3/spam/2669.2005-01-12.BG.spam.txt
#   inflating: corpus3/spam/0479.2004-09-05.BG.spam.txt
#   inflating: corpus3/spam/4173.2005-03-30.BG.spam.txt
#   inflating: corpus3/spam/1591.2004-11-13.BG.spam.txt
#   inflating: corpus3/spam/0474.2004-09-05.BG.spam.txt
#   inflating: corpus3/spam/0096.2004-08-07.BG.spam.txt
#   inflating: corpus3/spam/2285.2004-12-23.BG.spam.txt
#   inflating: corpus3/spam/3172.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/0382.2004-08-29.BG.spam.txt
#   inflating: corpus3/spam/5318.2005-06-17.BG.spam.txt
#   inflating: corpus3/spam/3742.2005-03-04.BG.spam.txt
#   inflating: corpus3/spam/2739.2005-01-15.BG.spam.txt
#   inflating: corpus3/spam/5134.2005-06-05.BG.spam.txt
#   inflating: corpus3/spam/0093.2004-08-07.BG.spam.txt
#   inflating: corpus3/spam/0477.2004-09-05.BG.spam.txt
#   inflating: corpus3/spam/1239.2004-10-26.BG.spam.txt
#   inflating: corpus3/spam/4600.2005-04-29.BG.spam.txt
#   inflating: corpus3/spam/2283.2004-12-23.BG.spam.txt
#   inflating: corpus3/spam/3868.2005-03-12.BG.spam.txt
#   inflating: corpus3/spam/2756.2005-01-16.BG.spam.txt
#   inflating: corpus3/spam/3776.2005-03-05.BG.spam.txt
#   inflating: corpus3/spam/1195.2004-10-23.BG.spam.txt
#   inflating: corpus3/spam/3240.2005-02-05.BG.spam.txt
#   inflating: corpus3/spam/5766.2005-07-15.BG.spam.txt
#   inflating: corpus3/spam/3208.2005-02-04.BG.spam.txt
#   inflating: corpus3/spam/1057.2004-10-15.BG.spam.txt
#   inflating: corpus3/spam/1004.2004-10-10.BG.spam.txt
#   inflating: corpus3/spam/3296.2005-02-07.BG.spam.txt
#   inflating: corpus3/spam/4525.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/0317.2004-08-23.BG.spam.txt
#   inflating: corpus3/spam/5235.2005-06-11.BG.spam.txt
#   inflating: corpus3/spam/1830.2004-11-26.BG.spam.txt
#   inflating: corpus3/spam/4328.2005-04-10.BG.spam.txt
#   inflating: corpus3/spam/3215.2005-02-04.BG.spam.txt
#   inflating: corpus3/spam/5958.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/2935.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/4091.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/3598.2005-02-21.BG.spam.txt
#   inflating: corpus3/spam/3049.2005-01-27.BG.spam.txt
#   inflating: corpus3/spam/2001.2004-12-08.BG.spam.txt
#   inflating: corpus3/spam/1437.2004-11-06.BG.spam.txt
#   inflating: corpus3/spam/4884.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/2451.2005-01-01.BG.spam.txt
#   inflating: corpus3/spam/1956.2004-12-04.BG.spam.txt
#   inflating: corpus3/spam/1829.2004-11-26.BG.spam.txt
#   inflating: corpus3/spam/3102.2005-01-30.BG.spam.txt
#   inflating: corpus3/spam/1912.2004-12-01.BG.spam.txt
#   inflating: corpus3/spam/4364.2005-04-12.BG.spam.txt
#   inflating: corpus3/spam/4034.2005-03-21.BG.spam.txt
#   inflating: corpus3/spam/4807.2005-05-13.BG.spam.txt
#   inflating: corpus3/spam/0874.2004-10-02.BG.spam.txt
#   inflating: corpus3/spam/2945.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/4903.2005-05-19.BG.spam.txt
#   inflating: corpus3/spam/3159.2005-02-01.BG.spam.txt
#   inflating: corpus3/spam/0429.2004-09-01.BG.spam.txt
#   inflating: corpus3/spam/0478.2004-09-05.BG.spam.txt
#   inflating: corpus3/spam/3497.2005-02-17.BG.spam.txt
#   inflating: corpus3/spam/4373.2005-04-13.BG.spam.txt
#   inflating: corpus3/spam/2075.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/2351.2004-12-26.BG.spam.txt
#   inflating: corpus3/spam/1385.2004-11-02.BG.spam.txt
#   inflating: corpus3/spam/0846.2004-09-30.BG.spam.txt
#   inflating: corpus3/spam/0730.2004-09-22.BG.spam.txt
#   inflating: corpus3/spam/4269.2005-04-07.BG.spam.txt
#   inflating: corpus3/spam/5528.2005-07-01.BG.spam.txt
#   inflating: corpus3/spam/2864.2005-01-20.BG.spam.txt
#   inflating: corpus3/spam/3946.2005-03-16.BG.spam.txt
#   inflating: corpus3/spam/3078.2005-01-29.BG.spam.txt
#   inflating: corpus3/spam/5380.2005-06-21.BG.spam.txt
#   inflating: corpus3/spam/3363.2005-02-10.BG.spam.txt
#   inflating: corpus3/spam/0243.2004-08-18.BG.spam.txt
#   inflating: corpus3/spam/2992.2005-01-24.BG.spam.txt
#   inflating: corpus3/spam/5598.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/3836.2005-03-09.BG.spam.txt
#   inflating: corpus3/spam/1176.2004-10-22.BG.spam.txt
#   inflating: corpus3/spam/5909.2005-07-22.BG.spam.txt
#   inflating: corpus3/spam/0335.2004-08-25.BG.spam.txt
#   inflating: corpus3/spam/3743.2005-03-04.BG.spam.txt
#   inflating: corpus3/spam/2393.2004-12-28.BG.spam.txt
#   inflating: corpus3/spam/2512.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/2659.2005-01-11.BG.spam.txt
#   inflating: corpus3/spam/2511.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/3727.2005-03-03.BG.spam.txt
#   inflating: corpus3/spam/3841.2005-03-09.BG.spam.txt
#   inflating: corpus3/spam/3718.2005-03-02.BG.spam.txt
#   inflating: corpus3/spam/3451.2005-02-15.BG.spam.txt
#   inflating: corpus3/spam/2146.2004-12-16.BG.spam.txt
#   inflating: corpus3/spam/2786.2005-01-17.BG.spam.txt
#   inflating: corpus3/spam/3968.2005-03-17.BG.spam.txt
#   inflating: corpus3/spam/2421.2004-12-30.BG.spam.txt
#   inflating: corpus3/spam/4164.2005-03-30.BG.spam.txt
#   inflating: corpus3/spam/2250.2004-12-21.BG.spam.txt
#   inflating: corpus3/spam/3673.2005-02-27.BG.spam.txt
#   inflating: corpus3/spam/4668.2005-05-04.BG.spam.txt
#   inflating: corpus3/spam/0439.2004-09-02.BG.spam.txt
#   inflating: corpus3/spam/5811.2005-07-17.BG.spam.txt
#   inflating: corpus3/spam/5378.2005-06-21.BG.spam.txt
#   inflating: corpus3/spam/3427.2005-02-14.BG.spam.txt
#   inflating: corpus3/spam/5014.2005-05-27.BG.spam.txt
#   inflating: corpus3/spam/2829.2005-01-19.BG.spam.txt
#   inflating: corpus3/spam/0432.2004-09-01.BG.spam.txt
#   inflating: corpus3/spam/2118.2004-12-14.BG.spam.txt
#   inflating: corpus3/spam/2999.2005-01-25.BG.spam.txt
#   inflating: corpus3/spam/3095.2005-01-30.BG.spam.txt
#   inflating: corpus3/spam/2483.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/3573.2005-02-20.BG.spam.txt
#   inflating: corpus3/spam/4394.2005-04-14.BG.spam.txt
#   inflating: corpus3/spam/2498.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/1629.2004-11-16.BG.spam.txt
#   inflating: corpus3/spam/5965.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/1513.2004-11-09.BG.spam.txt
#   inflating: corpus3/spam/3200.2005-02-03.BG.spam.txt
#   inflating: corpus3/spam/4482.2005-04-21.BG.spam.txt
#   inflating: corpus3/spam/3907.2005-03-14.BG.spam.txt
#   inflating: corpus3/spam/2658.2005-01-11.BG.spam.txt
#   inflating: corpus3/spam/2016.2004-12-09.BG.spam.txt
#   inflating: corpus3/spam/1566.2004-11-12.BG.spam.txt
#   inflating: corpus3/spam/1607.2004-11-14.BG.spam.txt
#   inflating: corpus3/spam/2470.2005-01-02.BG.spam.txt
#   inflating: corpus3/spam/3933.2005-03-15.BG.spam.txt
#   inflating: corpus3/spam/2586.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/3191.2005-02-02.BG.spam.txt
#   inflating: corpus3/spam/0678.2004-09-18.BG.spam.txt
#   inflating: corpus3/spam/5543.2005-07-03.BG.spam.txt
#   inflating: corpus3/spam/1576.2004-11-12.BG.spam.txt
#   inflating: corpus3/spam/4677.2005-05-05.BG.spam.txt
#   inflating: corpus3/spam/3405.2005-02-12.BG.spam.txt
#   inflating: corpus3/spam/2510.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/5128.2005-06-05.BG.spam.txt
#   inflating: corpus3/spam/1717.2004-11-20.BG.spam.txt
#   inflating: corpus3/spam/0451.2004-09-03.BG.spam.txt
#   inflating: corpus3/spam/1223.2004-10-25.BG.spam.txt
#   inflating: corpus3/spam/0253.2004-08-19.BG.spam.txt
#   inflating: corpus3/spam/1552.2004-11-11.BG.spam.txt
#   inflating: corpus3/spam/2076.2004-12-12.BG.spam.txt
#   inflating: corpus3/spam/4519.2005-04-24.BG.spam.txt
#   inflating: corpus3/spam/1642.2004-11-17.BG.spam.txt
#   inflating: corpus3/spam/5837.2005-07-19.BG.spam.txt
#   inflating: corpus3/spam/3983.2005-03-18.BG.spam.txt
#   inflating: corpus3/spam/3019.2005-01-25.BG.spam.txt
#   inflating: corpus3/spam/4946.2005-05-22.BG.spam.txt
#   inflating: corpus3/spam/3586.2005-02-21.BG.spam.txt
#   inflating: corpus3/spam/4184.2005-03-31.BG.spam.txt
#   inflating: corpus3/spam/1161.2004-10-22.BG.spam.txt
#   inflating: corpus3/spam/3127.2005-01-31.BG.spam.txt
#   inflating: corpus3/spam/0086.2004-08-07.BG.spam.txt
#   inflating: corpus3/spam/2585.2005-01-07.BG.spam.txt
#   inflating: corpus3/spam/0588.2004-09-14.BG.spam.txt
#   inflating: corpus3/spam/0646.2004-09-17.BG.spam.txt
#   inflating: corpus3/spam/1692.2004-11-19.BG.spam.txt
#   inflating: corpus3/spam/0542.2004-09-10.BG.spam.txt
#   inflating: corpus3/spam/1761.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/1030.2004-10-13.BG.spam.txt
#   inflating: corpus3/spam/1106.2004-10-18.BG.spam.txt
#   inflating: corpus3/spam/0069.2004-08-05.BG.spam.txt
#   inflating: corpus3/spam/3641.2005-02-25.BG.spam.txt
#   inflating: corpus3/spam/2874.2005-01-21.BG.spam.txt
#   inflating: corpus3/spam/1356.2004-11-01.BG.spam.txt
#   inflating: corpus3/spam/4512.2005-04-23.BG.spam.txt
#   inflating: corpus3/spam/1144.2004-10-20.BG.spam.txt
#   inflating: corpus3/spam/5542.2005-07-03.BG.spam.txt
#   inflating: corpus3/spam/2471.2005-01-02.BG.spam.txt
#   inflating: corpus3/spam/1665.2004-11-18.BG.spam.txt
#   inflating: corpus3/spam/4163.2005-03-30.BG.spam.txt
#   inflating: corpus3/spam/1319.2004-10-29.BG.spam.txt
#   inflating: corpus3/spam/2766.2005-01-17.BG.spam.txt
#   inflating: corpus3/spam/0642.2004-09-17.BG.spam.txt
#   inflating: corpus3/spam/3923.2005-03-15.BG.spam.txt
#   inflating: corpus3/spam/4457.2005-04-19.BG.spam.txt
#   inflating: corpus3/spam/2918.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/3724.2005-03-03.BG.spam.txt
#   inflating: corpus3/spam/0367.2004-08-27.BG.spam.txt
#   inflating: corpus3/spam/4509.2005-04-23.BG.spam.txt
#   inflating: corpus3/spam/0273.2004-08-20.BG.spam.txt
#   inflating: corpus3/spam/0606.2004-09-15.BG.spam.txt
#   inflating: corpus3/spam/5600.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/4911.2005-05-20.BG.spam.txt
#   inflating: corpus3/spam/5107.2005-06-03.BG.spam.txt
#   inflating: corpus3/spam/2172.2004-12-18.BG.spam.txt
#   inflating: corpus3/spam/0164.2004-08-12.BG.spam.txt
#   inflating: corpus3/spam/4961.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/0206.2004-08-15.BG.spam.txt
#   inflating: corpus3/spam/2516.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/3327.2005-02-08.BG.spam.txt
#   inflating: corpus3/spam/1411.2004-11-04.BG.spam.txt
#   inflating: corpus3/spam/1039.2004-10-14.BG.spam.txt
#   inflating: corpus3/spam/5882.2005-07-21.BG.spam.txt
#   inflating: corpus3/spam/5508.2005-06-30.BG.spam.txt
#   inflating: corpus3/spam/4702.2005-05-06.BG.spam.txt
#   inflating: corpus3/spam/3796.2005-03-07.BG.spam.txt
#   inflating: corpus3/spam/1898.2004-11-30.BG.spam.txt
#   inflating: corpus3/spam/2350.2004-12-25.BG.spam.txt
#   inflating: corpus3/spam/1603.2004-11-14.BG.spam.txt
#   inflating: corpus3/spam/2732.2005-01-15.BG.spam.txt
#   inflating: corpus3/spam/1600.2004-11-13.BG.spam.txt
#   inflating: corpus3/spam/4962.2005-05-23.BG.spam.txt
#   inflating: corpus3/spam/2641.2005-01-10.BG.spam.txt
#   inflating: corpus3/spam/3788.2005-03-06.BG.spam.txt
#   inflating: corpus3/spam/5859.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/3975.2005-03-18.BG.spam.txt
#   inflating: corpus3/spam/5620.2005-07-07.BG.spam.txt
#   inflating: corpus3/spam/5962.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/3030.2005-01-26.BG.spam.txt
#   inflating: corpus3/spam/2623.2005-01-10.BG.spam.txt
#   inflating: corpus3/spam/4934.2005-05-21.BG.spam.txt
#   inflating: corpus3/spam/2715.2005-01-14.BG.spam.txt
#   inflating: corpus3/spam/1547.2004-11-10.BG.spam.txt
#   inflating: corpus3/spam/4754.2005-05-09.BG.spam.txt
#   inflating: corpus3/spam/2958.2005-01-23.BG.spam.txt
#   inflating: corpus3/spam/4841.2005-05-15.BG.spam.txt
#   inflating: corpus3/spam/2208.2004-12-19.BG.spam.txt
#   inflating: corpus3/spam/2536.2005-01-05.BG.spam.txt
#   inflating: corpus3/spam/3792.2005-03-07.BG.spam.txt
#   inflating: corpus3/spam/5369.2005-06-21.BG.spam.txt
#   inflating: corpus3/spam/3089.2005-01-30.BG.spam.txt
#   inflating: corpus3/spam/4653.2005-05-02.BG.spam.txt
#   inflating: corpus3/spam/5052.2005-05-29.BG.spam.txt
#   inflating: corpus3/spam/0863.2004-10-01.BG.spam.txt
#   inflating: corpus3/spam/2896.2005-01-21.BG.spam.txt
#   inflating: corpus3/spam/1632.2004-11-16.BG.spam.txt
#   inflating: corpus3/spam/5823.2005-07-18.BG.spam.txt
#   inflating: corpus3/spam/4764.2005-05-10.BG.spam.txt
#   inflating: corpus3/spam/0277.2004-08-20.BG.spam.txt
#   inflating: corpus3/spam/1060.2004-10-15.BG.spam.txt
#   inflating: corpus3/spam/4144.2005-03-28.BG.spam.txt
#   inflating: corpus3/spam/0259.2004-08-19.BG.spam.txt
#   inflating: corpus3/spam/3547.2005-02-20.BG.spam.txt
#   inflating: corpus3/spam/4555.2005-04-26.BG.spam.txt
#   inflating: corpus3/spam/1291.2004-10-28.BG.spam.txt
#   inflating: corpus3/spam/4054.2005-03-23.BG.spam.txt
#   inflating: corpus3/spam/3739.2005-03-04.BG.spam.txt
#   inflating: corpus3/spam/3509.2005-02-18.BG.spam.txt
#   inflating: corpus3/spam/5964.2005-07-28.BG.spam.txt
#   inflating: corpus3/spam/2364.2004-12-27.BG.spam.txt
#   inflating: corpus3/spam/3347.2005-02-09.BG.spam.txt
#   inflating: corpus3/spam/1939.2004-12-02.BG.spam.txt
#   inflating: corpus3/spam/1738.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/3262.2005-02-05.BG.spam.txt
#   inflating: corpus3/spam/4781.2005-05-11.BG.spam.txt
#   inflating: corpus3/spam/5288.2005-06-15.BG.spam.txt
#   inflating: corpus3/spam/2944.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/0145.2004-08-11.BG.spam.txt
#   inflating: corpus3/spam/1640.2004-11-17.BG.spam.txt
#   inflating: corpus3/spam/0047.2004-08-04.BG.spam.txt
#   inflating: corpus3/spam/5169.2005-06-07.BG.spam.txt
#   inflating: corpus3/spam/3551.2005-02-20.BG.spam.txt
#   inflating: corpus3/spam/4836.2005-05-15.BG.spam.txt
#   inflating: corpus3/spam/1559.2004-11-11.BG.spam.txt
#   inflating: corpus3/spam/5616.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/4872.2005-05-18.BG.spam.txt
#   inflating: corpus3/spam/2930.2005-01-22.BG.spam.txt
#   inflating: corpus3/spam/4162.2005-03-30.BG.spam.txt
#   inflating: corpus3/spam/1924.2004-12-01.BG.spam.txt
#   inflating: corpus3/spam/0471.2004-09-04.BG.spam.txt
#   inflating: corpus3/spam/2960.2005-01-23.BG.spam.txt
#   inflating: corpus3/spam/0028.2004-08-02.BG.spam.txt
#   inflating: corpus3/spam/1777.2004-11-23.BG.spam.txt
#   inflating: corpus3/spam/4294.2005-04-08.BG.spam.txt
#   inflating: corpus3/spam/4942.2005-05-21.BG.spam.txt
#   inflating: corpus3/spam/0372.2004-08-28.BG.spam.txt
#   inflating: corpus3/spam/4825.2005-05-15.BG.spam.txt
#   inflating: corpus3/spam/1955.2004-12-04.BG.spam.txt
#   inflating: corpus3/spam/3411.2005-02-12.BG.spam.txt
#   inflating: corpus3/spam/4783.2005-05-11.BG.spam.txt
#   inflating: corpus3/spam/3438.2005-02-14.BG.spam.txt
#   inflating: corpus3/spam/1546.2004-11-10.BG.spam.txt
#   inflating: corpus3/spam/5851.2005-07-20.BG.spam.txt
#   inflating: corpus3/spam/2449.2005-01-01.BG.spam.txt
#   inflating: corpus3/spam/0631.2004-09-16.BG.spam.txt
#   inflating: corpus3/spam/4057.2005-03-23.BG.spam.txt
#   inflating: corpus3/spam/4689.2005-05-05.BG.spam.txt
#   inflating: corpus3/spam/0996.2004-10-10.BG.spam.txt
#   inflating: corpus3/spam/1844.2004-11-27.BG.spam.txt
#   inflating: corpus3/spam/3730.2005-03-03.BG.spam.txt
#   inflating: corpus3/spam/1010.2004-10-11.BG.spam.txt
#   inflating: corpus3/spam/2792.2005-01-18.BG.spam.txt
#   inflating: corpus3/spam/5646.2005-07-08.BG.spam.txt
#   inflating: corpus3/spam/1316.2004-10-29.BG.spam.txt
#   inflating: corpus3/spam/4088.2005-03-24.BG.spam.txt
#   inflating: corpus3/spam/3135.2005-01-31.BG.spam.txt
#   inflating: corpus3/spam/5323.2005-06-18.BG.spam.txt
#   inflating: corpus3/spam/4044.2005-03-22.BG.spam.txt
#   inflating: corpus3/spam/0973.2004-10-08.BG.spam.txt
#   inflating: corpus3/spam/0725.2004-09-21.BG.spam.txt
#   inflating: corpus3/spam/4416.2005-04-16.BG.spam.txt
#   inflating: corpus3/spam/0424.2004-08-31.BG.spam.txt
#   inflating: corpus3/spam/6000.2005-07-31.BG.spam.txt
#   inflating: corpus3/spam/0346.2004-08-26.BG.spam.txt
#   inflating: corpus3/spam/0721.2004-09-21.BG.spam.txt
#   inflating: corpus3/spam/0523.2004-09-08.BG.spam.txt
#   inflating: corpus3/spam/4338.2005-04-10.BG.spam.txt
#   inflating: corpus3/spam/5751.2005-07-15.BG.spam.txt
#   inflating: corpus3/spam/0961.2004-10-08.BG.spam.txt
#   inflating: corpus3/spam/5916.2005-07-23.BG.spam.txt
#   inflating: corpus3/spam/4193.2005-04-01.BG.spam.txt
#   inflating: corpus3/spam/0067.2004-08-05.BG.spam.txt
#   inflating: corpus3/spam/5982.2005-07-29.BG.spam.txt
#   inflating: corpus3/spam/0413.2004-08-31.BG.spam.txt
#   inflating: corpus3/spam/4617.2005-05-01.BG.spam.txt
#   inflating: corpus3/spam/5482.2005-06-29.BG.spam.txt
#   inflating: corpus3/spam/5149.2005-06-06.BG.spam.txt
#   inflating: corpus3/spam/0790.2004-09-27.BG.spam.txt
#   inflating: corpus3/spam/3246.2005-02-05.BG.spam.txt
#   inflating: corpus3/spam/3197.2005-02-03.BG.spam.txt
#   inflating: corpus3/spam/0820.2004-09-28.BG.spam.txt
#   inflating: corpus3/spam/5237.2005-06-11.BG.spam.txt
#   inflating: corpus3/spam/5908.2005-07-22.BG.spam.txt
#   inflating: corpus3/spam/1468.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/1689.2004-11-19.BG.spam.txt
#   inflating: corpus3/spam/1092.2004-10-17.BG.spam.txt
#   inflating: corpus3/spam/0323.2004-08-23.BG.spam.txt
#   inflating: corpus3/spam/2779.2005-01-17.BG.spam.txt
#   inflating: corpus3/spam/1132.2004-10-19.BG.spam.txt
#   inflating: corpus3/spam/5970.2005-07-29.BG.spam.txt
#   inflating: corpus3/spam/1288.2004-10-28.BG.spam.txt
#   inflating: corpus3/spam/5614.2005-07-06.BG.spam.txt
#   inflating: corpus3/spam/0891.2004-10-03.BG.spam.txt
#   inflating: corpus3/spam/5300.2005-06-16.BG.spam.txt
#   inflating: corpus3/spam/0881.2004-10-03.BG.spam.txt
#   inflating: corpus3/spam/0809.2004-09-28.BG.spam.txt
#   inflating: corpus3/spam/3622.2005-02-23.BG.spam.txt
#   inflating: corpus3/spam/0694.2004-09-20.BG.spam.txt
#   inflating: corpus3/spam/0427.2004-09-01.BG.spam.txt
#   inflating: corpus3/spam/0468.2004-09-04.BG.spam.txt
#   inflating: corpus3/spam/5097.2005-06-02.BG.spam.txt
#   inflating: corpus3/spam/1764.2004-11-22.BG.spam.txt
#   inflating: corpus3/spam/1432.2004-11-06.BG.spam.txt
#   inflating: corpus3/spam/1718.2004-11-20.BG.spam.txt
#   inflating: corpus3/spam/1691.2004-11-19.BG.spam.txt
#   inflating: corpus3/spam/4913.2005-05-20.BG.spam.txt
#   inflating: corpus3/spam/1474.2004-11-07.BG.spam.txt
#   inflating: corpus3/spam/5173.2005-06-08.BG.spam.txt
#   inflating: corpus3/spam/4790.2005-05-12.BG.spam.txt
#   inflating: corpus3/spam/2638.2005-01-10.BG.spam.txt
#   inflating: corpus3/spam/4041.2005-03-21.BG.spam.txt
#   inflating: corpus3/spam/1521.2004-11-09.BG.spam.txt
#   inflating: corpus3/spam/2793.2005-01-18.BG.spam.txt
#   inflating: corpus3/spam/2499.2005-01-03.BG.spam.txt
#   inflating: corpus3/spam/1303.2004-10-29.BG.spam.txt
#   inflating: corpus3/spam/5349.2005-06-19.BG.spam.txt
# ...
#   inflating: corpus3/ham/5039.2001-11-26.lokay.ham.txt
#   inflating: corpus3/ham/5765.2002-03-01.lokay.ham.txt
#   inflating: corpus3/ham/3735.2001-06-11.lokay.ham.txt
#   inflating: corpus3/ham/3977.2001-07-17.lokay.ham.txt
#   inflating: corpus3/ham/2137.2000-12-04.lokay.ham.txt
#   inflating: corpus3/ham/2376.2001-01-04.lokay.ham.txt
#   inflating: corpus3/ham/5079.2001-12-03.lokay.ham.txt
#   inflating: corpus3/ham/0913.2000-08-31.lokay.ham.txt
#   inflating: corpus3/ham/3512.2001-04-26.lokay.ham.txt
#   inflating: corpus3/ham/2969.2001-02-02.lokay.ham.txt
#   inflating: corpus3/ham/4772.2001-10-18.lokay.ham.txt
#   inflating: corpus3/ham/5593.2002-02-12.lokay.ham.txt
#   inflating: corpus3/ham/3063.2001-02-15.lokay.ham.txt
#   inflating: corpus3/ham/0844.2000-08-24.lokay.ham.txt
#   inflating: corpus3/ham/3349.2001-03-30.lokay.ham.txt
#   inflating: corpus3/ham/3597.2001-05-16.lokay.ham.txt
#   inflating: corpus3/ham/4226.2001-08-14.lokay.ham.txt
#   inflating: corpus3/ham/5261.2002-01-09.lokay.ham.txt
#   inflating: corpus3/ham/5171.2001-12-18.lokay.ham.txt
#   inflating: corpus3/ham/2482.2001-01-11.lokay.ham.txt
#   inflating: corpus3/ham/1688.2000-11-02.lokay.ham.txt
#   inflating: corpus3/ham/3713.2001-06-06.lokay.ham.txt
#   inflating: corpus3/ham/5493.2002-02-01.lokay.ham.txt
#   inflating: corpus3/ham/1419.2000-10-13.lokay.ham.txt
#   inflating: corpus3/ham/3371.2001-04-08.lokay.ham.txt
#   inflating: corpus3/ham/0570.2000-07-28.lokay.ham.txt
#   inflating: corpus3/ham/1410.2000-10-12.lokay.ham.txt
#   inflating: corpus3/ham/3662.2001-06-01.lokay.ham.txt
#   inflating: corpus3/ham/4605.2001-09-28.lokay.ham.txt
#   inflating: corpus3/ham/0073.2000-06-15.lokay.ham.txt
#   inflating: corpus3/ham/4292.2001-08-22.lokay.ham.txt
#   inflating: corpus3/ham/2177.2000-12-05.lokay.ham.txt
#   inflating: corpus3/ham/1825.2000-11-10.lokay.ham.txt
#   inflating: corpus3/ham/3655.2001-05-31.lokay.ham.txt
#   inflating: corpus3/ham/3808.2001-06-21.lokay.ham.txt
#   inflating: corpus3/ham/3685.2001-06-05.lokay.ham.txt
#   inflating: corpus3/ham/4285.2001-08-21.lokay.ham.txt
#   inflating: corpus3/ham/4912.2001-10-31.lokay.ham.txt
#   inflating: corpus3/ham/2698.2001-01-24.lokay.ham.txt
#   inflating: corpus3/ham/3012.2001-02-08.lokay.ham.txt
#   inflating: corpus3/ham/5712.2002-02-27.lokay.ham.txt
#   inflating: corpus3/ham/2853.2001-01-30.lokay.ham.txt
#   inflating: corpus3/ham/2007.2000-11-22.lokay.ham.txt
#   inflating: corpus3/ham/3317.2001-03-23.lokay.ham.txt
#   inflating: corpus3/ham/0015.2000-06-09.lokay.ham.txt
#   inflating: corpus3/ham/5729.2002-02-27.lokay.ham.txt
#   inflating: corpus3/ham/0154.2000-06-26.lokay.ham.txt
#   inflating: corpus3/ham/5816.2002-03-06.lokay.ham.txt
#   inflating: corpus3/ham/4242.2001-08-14.lokay.ham.txt
#   inflating: corpus3/ham/5472.2002-01-31.lokay.ham.txt
#   inflating: corpus3/ham/5879.2002-03-12.lokay.ham.txt
#   inflating: corpus3/ham/5293.2002-01-10.lokay.ham.txt
#   inflating: corpus3/ham/0919.2000-08-31.lokay.ham.txt
#   inflating: corpus3/ham/3428.2001-04-17.lokay.ham.txt
#   inflating: corpus3/ham/4156.2001-08-06.lokay.ham.txt
#   inflating: corpus3/ham/3374.2001-04-09.lokay.ham.txt
#   inflating: corpus3/ham/1167.2000-09-22.lokay.ham.txt
#   inflating: corpus3/ham/2657.2001-01-21.lokay.ham.txt
#   inflating: corpus3/ham/5929.2002-03-19.lokay.ham.txt
#   inflating: corpus3/ham/4016.2001-07-19.lokay.ham.txt
#   inflating: corpus3/ham/2636.2001-01-19.lokay.ham.txt
#   inflating: corpus3/ham/2948.2001-02-02.lokay.ham.txt
#   inflating: corpus3/ham/3960.2001-07-17.lokay.ham.txt
#   inflating: corpus3/ham/2706.2001-01-24.lokay.ham.txt
#   inflating: corpus3/ham/5033.2001-11-26.lokay.ham.txt
#   inflating: corpus3/ham/5988.2002-03-25.lokay.ham.txt
#   inflating: corpus3/ham/1153.2000-09-22.lokay.ham.txt
#   inflating: corpus3/ham/0953.2000-09-05.lokay.ham.txt
#   inflating: corpus3/ham/1506.2000-10-23.lokay.ham.txt
#   inflating: corpus3/ham/1969.2000-11-17.lokay.ham.txt
#   inflating: corpus3/ham/1927.2000-11-16.lokay.ham.txt
#   inflating: corpus3/ham/0066.2000-06-15.lokay.ham.txt
#   inflating: corpus3/ham/0122.2000-06-21.lokay.ham.txt
#   inflating: corpus3/ham/1489.2000-10-20.lokay.ham.txt
#   inflating: corpus3/ham/1776.2000-11-08.lokay.ham.txt
#   inflating: corpus3/ham/4209.2001-08-12.lokay.ham.txt
#   inflating: corpus3/ham/4687.2001-10-05.lokay.ham.txt
#   inflating: corpus3/ham/2701.2001-01-24.lokay.ham.txt
#   inflating: corpus3/ham/1583.2000-10-27.lokay.ham.txt
#   inflating: corpus3/ham/1608.2000-10-30.lokay.ham.txt
#   inflating: corpus3/ham/1174.2000-09-26.lokay.ham.txt
#   inflating: corpus3/ham/1699.2000-11-03.lokay.ham.txt
#   inflating: corpus3/ham/2711.2001-01-25.lokay.ham.txt
#   inflating: corpus3/ham/4073.2001-07-31.lokay.ham.txt
#   inflating: corpus3/ham/4821.2001-10-24.lokay.ham.txt
#   inflating: corpus3/ham/2556.2001-01-17.lokay.ham.txt
#   inflating: corpus3/ham/3270.2001-03-19.lokay.ham.txt
#   inflating: corpus3/ham/2642.2001-01-19.lokay.ham.txt
#   inflating: corpus3/ham/1366.2000-10-09.lokay.ham.txt
#  extracting: corpus3/ham/0651.2000-08-07.lokay.ham.txt
#   inflating: corpus3/ham/1255.2000-10-02.lokay.ham.txt
#   inflating: corpus3/ham/0654.2000-08-07.lokay.ham.txt
#   inflating: corpus3/ham/2281.2000-12-20.lokay.ham.txt
#   inflating: corpus3/ham/2366.2001-01-02.lokay.ham.txt
#   inflating: corpus3/ham/3955.2001-07-16.lokay.ham.txt
#   inflating: corpus3/ham/3098.2001-02-16.lokay.ham.txt
#   inflating: corpus3/ham/5967.2002-03-25.lokay.ham.txt
#   inflating: corpus3/ham/4511.2001-09-19.lokay.ham.txt
#   inflating: corpus3/ham/2910.2001-02-01.lokay.ham.txt
#   inflating: corpus3/ham/0158.2000-06-26.lokay.ham.txt
#   inflating: corpus3/ham/2225.2000-12-12.lokay.ham.txt
#   inflating: corpus3/ham/3304.2001-03-21.lokay.ham.txt
#   inflating: corpus3/ham/4481.2001-09-10.lokay.ham.txt
#   inflating: corpus3/ham/2696.2001-01-24.lokay.ham.txt
#   inflating: corpus3/ham/0221.2000-06-30.lokay.ham.txt
#   inflating: corpus3/ham/3966.2001-07-17.lokay.ham.txt
#   inflating: corpus3/ham/4068.2001-07-30.lokay.ham.txt
#   inflating: corpus3/ham/5774.2002-03-01.lokay.ham.txt
#   inflating: corpus3/ham/5446.2002-01-30.lokay.ham.txt
#   inflating: corpus3/ham/0132.2000-06-22.lokay.ham.txt
#   inflating: corpus3/ham/4804.2001-10-22.lokay.ham.txt
#   inflating: corpus3/ham/0219.2000-06-30.lokay.ham.txt
#   inflating: corpus3/ham/2472.2001-01-11.lokay.ham.txt
#   inflating: corpus3/ham/5425.2002-01-28.lokay.ham.txt
#   inflating: corpus3/ham/2883.2001-01-31.lokay.ham.txt
#   inflating: corpus3/ham/4556.2001-09-24.lokay.ham.txt
#   inflating: corpus3/ham/1190.2000-09-27.lokay.ham.txt
#   inflating: corpus3/ham/5524.2002-02-05.lokay.ham.txt
#   inflating: corpus3/ham/5519.2002-02-05.lokay.ham.txt
#   inflating: corpus3/ham/3827.2001-06-22.lokay.ham.txt
#   inflating: corpus3/ham/0497.2000-07-21.lokay.ham.txt
#   inflating: corpus3/ham/1397.2000-10-12.lokay.ham.txt
#   inflating: corpus3/ham/5021.2001-11-21.lokay.ham.txt
#   inflating: corpus3/ham/2420.2001-01-08.lokay.ham.txt
#   inflating: corpus3/ham/4309.2001-08-23.lokay.ham.txt
#   inflating: corpus3/ham/0873.2000-08-25.lokay.ham.txt
#   inflating: corpus3/ham/0775.2000-08-17.lokay.ham.txt
#  extracting: corpus3/ham/5393.2002-01-24.lokay.ham.txt
#   inflating: corpus3/ham/2862.2001-01-30.lokay.ham.txt
#   inflating: corpus3/ham/1435.2000-10-13.lokay.ham.txt
#   inflating: corpus3/ham/2088.2000-11-30.lokay.ham.txt
#   inflating: corpus3/ham/1719.2000-11-06.lokay.ham.txt
#   inflating: corpus3/ham/4397.2001-08-30.lokay.ham.txt
#   inflating: corpus3/ham/5643.2002-02-19.lokay.ham.txt
#   inflating: corpus3/ham/1705.2000-11-03.lokay.ham.txt
#   inflating: corpus3/ham/0208.2000-06-29.lokay.ham.txt
#   inflating: corpus3/ham/4786.2001-10-18.lokay.ham.txt
#   inflating: corpus3/ham/1905.2000-11-15.lokay.ham.txt
#   inflating: corpus3/ham/2096.2000-12-01.lokay.ham.txt
#   inflating: corpus3/ham/1087.2000-09-15.lokay.ham.txt
#   inflating: corpus3/ham/3755.2001-06-12.lokay.ham.txt
#   inflating: corpus3/ham/5063.2001-11-28.lokay.ham.txt
#   inflating: corpus3/ham/1675.2000-11-02.lokay.ham.txt
#   inflating: corpus3/ham/0931.2000-09-01.lokay.ham.txt
#   inflating: corpus3/ham/0426.2000-07-19.lokay.ham.txt
#   inflating: corpus3/ham/5824.2002-03-07.lokay.ham.txt
#   inflating: corpus3/ham/3323.2001-03-26.lokay.ham.txt
#   inflating: corpus3/ham/2014.2000-11-22.lokay.ham.txt
#   inflating: corpus3/ham/2998.2001-02-07.lokay.ham.txt
#   inflating: corpus3/ham/4194.2001-08-10.lokay.ham.txt
#   inflating: corpus3/ham/3116.2001-02-20.lokay.ham.txt
#   inflating: corpus3/ham/5496.2002-02-01.lokay.ham.txt
#   inflating: corpus3/ham/4631.2001-10-01.lokay.ham.txt
#   inflating: corpus3/ham/5121.2001-12-12.lokay.ham.txt
#   inflating: corpus3/ham/4933.2001-11-02.lokay.ham.txt
#   inflating: corpus3/ham/4861.2001-10-26.lokay.ham.txt
#   inflating: corpus3/ham/2707.2001-01-24.lokay.ham.txt
#   inflating: corpus3/ham/2349.2001-01-02.lokay.ham.txt
#   inflating: corpus3/ham/5887.2002-03-14.lokay.ham.txt
#   inflating: corpus3/ham/0796.2000-08-21.lokay.ham.txt
#   inflating: corpus3/ham/2760.2001-01-26.lokay.ham.txt
#   inflating: corpus3/ham/1644.2000-11-01.lokay.ham.txt
#   inflating: corpus3/ham/5684.2002-02-21.lokay.ham.txt
#   inflating: corpus3/ham/4424.2001-09-04.lokay.ham.txt
#   inflating: corpus3/ham/1769.2000-11-08.lokay.ham.txt
#   inflating: corpus3/ham/0098.2000-06-20.lokay.ham.txt
#   inflating: corpus3/ham/2757.2001-01-26.lokay.ham.txt
#   inflating: corpus3/ham/1036.2000-09-13.lokay.ham.txt
#   inflating: corpus3/ham/3227.2001-03-12.lokay.ham.txt
#   inflating: corpus3/ham/2077.2000-11-30.lokay.ham.txt
#   inflating: corpus3/ham/5941.2002-03-20.lokay.ham.txt
#   inflating: corpus3/ham/3351.2001-03-30.lokay.ham.txt
#   inflating: corpus3/ham/4324.2001-08-25.lokay.ham.txt
#   inflating: corpus3/ham/5936.2002-03-19.lokay.ham.txt
#   inflating: corpus3/ham/1896.2000-11-15.lokay.ham.txt
#   inflating: corpus3/ham/0679.2000-08-08.lokay.ham.txt
#   inflating: corpus3/ham/5706.2002-02-25.lokay.ham.txt
#   inflating: corpus3/ham/1394.2000-10-12.lokay.ham.txt
#   inflating: corpus3/ham/2478.2001-01-11.lokay.ham.txt
#   inflating: corpus3/ham/5138.2001-12-13.lokay.ham.txt
#   inflating: corpus3/ham/5080.2001-12-04.lokay.ham.txt
#   inflating: corpus3/ham/5586.2002-02-11.lokay.ham.txt
#   inflating: corpus3/ham/2455.2001-01-10.lokay.ham.txt
#   inflating: corpus3/ham/2452.2001-01-10.lokay.ham.txt
#   inflating: corpus3/ham/2462.2001-01-10.lokay.ham.txt
#   inflating: corpus3/ham/1592.2000-10-30.lokay.ham.txt
#   inflating: corpus3/ham/3124.2001-02-21.lokay.ham.txt
#   inflating: corpus3/ham/3531.2001-05-01.lokay.ham.txt
#   inflating: corpus3/ham/2743.2001-01-26.lokay.ham.txt
#   inflating: corpus3/ham/2497.2001-01-11.lokay.ham.txt
#   inflating: corpus3/ham/0977.2000-09-06.lokay.ham.txt
#   inflating: corpus3/ham/4199.2001-08-10.lokay.ham.txt
#   inflating: corpus3/ham/4096.2001-08-01.lokay.ham.txt
#   inflating: corpus3/ham/4145.2001-08-05.lokay.ham.txt
#   inflating: corpus3/ham/5049.2001-11-28.lokay.ham.txt
#   inflating: corpus3/ham/0701.2000-08-10.lokay.ham.txt
#   inflating: corpus3/ham/5883.2002-03-13.lokay.ham.txt
#   inflating: corpus3/ham/4454.2001-09-06.lokay.ham.txt
#   inflating: corpus3/ham/0128.2000-06-22.lokay.ham.txt
#   inflating: corpus3/ham/1881.2000-11-14.lokay.ham.txt
#   inflating: corpus3/ham/3187.2001-03-05.lokay.ham.txt
#   inflating: corpus3/ham/4725.2001-10-09.lokay.ham.txt
#   inflating: corpus3/ham/1620.2000-10-31.lokay.ham.txt
#   inflating: corpus3/ham/5222.2002-01-02.lokay.ham.txt
#   inflating: corpus3/ham/3864.2001-06-27.lokay.ham.txt
#   inflating: corpus3/ham/1430.2000-10-13.lokay.ham.txt
#   inflating: corpus3/ham/0414.2000-07-17.lokay.ham.txt
#   inflating: corpus3/ham/5129.2001-12-13.lokay.ham.txt
#   inflating: corpus3/ham/4412.2001-08-31.lokay.ham.txt
#   inflating: corpus3/ham/4382.2001-08-28.lokay.ham.txt
#   inflating: corpus3/ham/0802.2000-08-21.lokay.ham.txt
#   inflating: corpus3/ham/2274.2000-12-18.lokay.ham.txt
#   inflating: corpus3/ham/1263.2000-10-04.lokay.ham.txt
#   inflating: corpus3/ham/2956.2001-02-02.lokay.ham.txt
#   inflating: corpus3/ham/4936.2001-11-02.lokay.ham.txt
#   inflating: corpus3/ham/2592.2001-01-18.lokay.ham.txt
#   inflating: corpus3/ham/3392.2001-04-12.lokay.ham.txt
#   inflating: corpus3/ham/1943.2000-11-16.lokay.ham.txt
#   inflating: corpus3/ham/5758.2002-03-01.lokay.ham.txt
#   inflating: corpus3/ham/5007.2001-11-16.lokay.ham.txt
#   inflating: corpus3/ham/4852.2001-10-25.lokay.ham.txt
#   inflating: corpus3/ham/1448.2000-10-16.lokay.ham.txt
#   inflating: corpus3/ham/3795.2001-06-18.lokay.ham.txt
#   inflating: corpus3/ham/3430.2001-04-18.lokay.ham.txt
#   inflating: corpus3/ham/2614.2001-01-19.lokay.ham.txt
#   inflating: corpus3/ham/1774.2000-11-08.lokay.ham.txt
#   inflating: corpus3/ham/4106.2001-08-02.lokay.ham.txt
#   inflating: corpus3/ham/1332.2000-10-06.lokay.ham.txt
#   inflating: corpus3/ham/4062.2001-07-30.lokay.ham.txt
#   inflating: corpus3/ham/0904.2000-08-31.lokay.ham.txt
#   inflating: corpus3/ham/2873.2001-01-30.lokay.ham.txt
#   inflating: corpus3/ham/2897.2001-01-31.lokay.ham.txt
#   inflating: corpus3/ham/4247.2001-08-14.lokay.ham.txt
#   inflating: corpus3/ham/5899.2002-03-15.lokay.ham.txt
#   inflating: corpus3/ham/5215.2002-01-02.lokay.ham.txt
#   inflating: corpus3/ham/3336.2001-03-27.lokay.ham.txt
#   inflating: corpus3/ham/1510.2000-10-24.lokay.ham.txt
#   inflating: corpus3/ham/3583.2001-05-10.lokay.ham.txt
#   inflating: corpus3/ham/4484.2001-09-13.lokay.ham.txt
#   inflating: corpus3/ham/3832.2001-06-22.lokay.ham.txt
#   inflating: corpus3/ham/4658.2001-10-04.lokay.ham.txt
#   inflating: corpus3/ham/5865.2002-03-12.lokay.ham.txt
#   inflating: corpus3/ham/2389.2001-01-04.lokay.ham.txt
#   inflating: corpus3/ham/5016.2001-11-19.lokay.ham.txt
#   inflating: corpus3/ham/3290.2001-03-19.lokay.ham.txt
#   inflating: corpus3/ham/3341.2001-03-28.lokay.ham.txt
#   inflating: corpus3/ham/0405.2000-07-17.lokay.ham.txt
#   inflating: corpus3/ham/0910.2000-08-31.lokay.ham.txt
#   inflating: corpus3/ham/0663.2000-08-08.lokay.ham.txt
#   inflating: corpus3/ham/0088.2000-06-19.lokay.ham.txt
#   inflating: corpus3/ham/1240.2000-10-02.lokay.ham.txt
#   inflating: corpus3/ham/5416.2002-01-25.lokay.ham.txt
#   inflating: corpus3/ham/0720.2000-08-11.lokay.ham.txt
#   inflating: corpus3/ham/0547.2000-07-27.lokay.ham.txt
#   inflating: corpus3/ham/0041.2000-06-13.lokay.ham.txt
#   inflating: corpus3/ham/2849.2001-01-30.lokay.ham.txt
#   inflating: corpus3/ham/3406.2001-04-13.lokay.ham.txt
#   inflating: corpus3/ham/4864.2001-10-26.lokay.ham.txt
#   inflating: corpus3/ham/4589.2001-09-26.lokay.ham.txt
#   inflating: corpus3/ham/3396.2001-04-12.lokay.ham.txt
#   inflating: corpus3/ham/1976.2000-11-20.lokay.ham.txt
#   inflating: corpus3/ham/3294.2001-03-21.lokay.ham.txt
#   inflating: corpus3/ham/0591.2000-08-01.lokay.ham.txt
#   inflating: corpus3/ham/3090.2001-02-16.lokay.ham.txt
#   inflating: corpus3/ham/4941.2001-11-06.lokay.ham.txt
#   inflating: corpus3/ham/0321.2000-07-12.lokay.ham.txt
#   inflating: corpus3/ham/4084.2001-08-01.lokay.ham.txt
#   inflating: corpus3/ham/0746.2000-08-15.lokay.ham.txt
#   inflating: corpus3/ham/2261.2000-12-15.lokay.ham.txt
#   inflating: corpus3/ham/3658.2001-06-01.lokay.ham.txt
#   inflating: corpus3/ham/1341.2000-10-09.lokay.ham.txt
#   inflating: corpus3/ham/1929.2000-11-16.lokay.ham.txt
#   inflating: corpus3/ham/4967.2001-11-12.lokay.ham.txt
#   inflating: corpus3/ham/3487.2001-04-25.lokay.ham.txt
#   inflating: corpus3/ham/1900.2000-11-15.lokay.ham.txt
#   inflating: corpus3/ham/1160.2000-09-22.lokay.ham.txt
#   inflating: corpus3/ham/0565.2000-07-28.lokay.ham.txt
#   inflating: corpus3/ham/0612.2000-08-03.lokay.ham.txt
#   inflating: corpus3/ham/0176.2000-06-27.lokay.ham.txt
#   inflating: corpus3/ham/2244.2000-12-13.lokay.ham.txt
# 16347
# 0.9862343224227592
