# %% [markdown]
# # Entrenando un Modelo Markoviano Latente (HMM)

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/

# %%
#@title dependencias previas
# !pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Collecting conllu
#   Downloading conllu-4.4.1-py2.py3-none-any.whl (15 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.4.1
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 875, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 875 (delta 90), reused 77 (delta 40), pack-reused 747
# Receiving objects: 100% (875/875), 289.14 MiB | 11.34 MiB/s, done.
# Resolving deltas: 100% (615/615), done.

# %%
#@title leyendo el corpus AnCora
from conllu import parse_incr 
wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")
for tokenlist in parse_incr(data_file):
    print(tokenlist.serialize())
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 2	informó	informar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	9	advcl	9:advcl	_
# 3	hoy	hoy	ADV	rg	_	2	advmod	2:advmod	_
# 4	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	5:det	_
# 5	Cadena	Cadena	PROPN	np00000	_	2	nsubj	2:nsubj	MWE=Cadena_Ser|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-s3.sn.10|ClusterType=Spec.organization|MentionSpan=4-6
# 6	Ser	Ser	PROPN	_	_	5	flat	5:flat	SpaceAfter=No
# 7	,	,	PUNCT	fc	PunctType=Comm	2	punct	2:punct	_
# 8	Benegas	Benegas	PROPN	np00000	_	9	nsubj	9:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=8|MentionMisc=CorefType:ident
# 9	sufrió	sufrir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 10	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	11	det	11:det	_
# 11	intento	intento	NOUN	ncms000	Gender=Masc|Number=Sing	9	obj	9:obj	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=10-13|MentionMisc=CorefType:ident
# 12	de	de	ADP	sps00	_	13	case	13:case	_
# 13	atentado	atentado	NOUN	ncms000	Gender=Masc|Number=Sing	11	nmod	11:nmod	_
# 14	por	por	ADP	sps00	_	17	case	17:case	MWE=por_parte_de|MWEPOS=ADP
# 15	parte	parte	NOUN	_	_	14	fixed	14:fixed	_
# 16	de	de	ADP	_	_	14	fixed	14:fixed	_
# 17	ETA	ETA	PROPN	np00000	_	9	obl	9:obl	ClusterId=CESS-CAST-AA-20000511-8193-c2|ClusterType=Spec.organization|MentionSpan=17|MentionMisc=CorefType:ident
# 18	en	en	ADP	sps00	_	20	case	20:case	_
# 19	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	20:det	_
# 20	portería	portería	NOUN	ncfs000	Gender=Fem|Number=Sing	9	obl	9:obl	ClusterId=CESS-CAST-AA-20000511-8193-s3.sn.41|ClusterType=Gen|MentionSpan=19-23|MentionMisc=HomoDD
# 21	de	de	ADP	sps00	_	23	case	23:case	_
# 22	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	23	det	23:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=22|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 23	vivienda	vivienda	NOUN	ncfs000	Gender=Fem|Number=Sing	20	nmod	20:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s3.sn.49|ClusterType=Gen|MentionSpan=22-23
# 24	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	26:det	_
# 25	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	26	amod	26:amod	_
# 26	lunes	lunes	NOUN	_	AdvType=Tim	9	obl	9:obl	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c4|ClusterType=Spec.date|MentionSpan=24-44|MentionMisc=CorefType:ident
# 27	,	,	PUNCT	fc	PunctType=Comm	30	punct	30:punct	_
# 28	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 29	día	día	NOUN	ncms000	Gender=Masc|Number=Sing	30	obl	30:obl	_
# 30	después	después	ADV	rg	_	26	advmod	26:advmod	_
# 31	de	de	ADP	sps00	_	36	mark	36:mark	_
# 32	que	que	SCONJ	cs	_	36	mark	36:mark	_
# 33	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	34	det	34:det	_
# 34	organización	organización	NOUN	ncfs000	Gender=Fem|Number=Sing	36	nsubj	36:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c2|ClusterType=Spec.organization|MentionSpan=33-35|MentionMisc=ClusterTypeMismatch:Spec:Spec.organization,CorefType:ident
# 35	terrorista	terrorista	ADJ	aq0cs0	Number=Sing	34	amod	34:amod	_
# 36	asesinara	asesinar	VERB	vmsi3s0	Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	30	advcl	30:advcl	_
# 37	en	en	ADP	sps00	_	38	case	38:case	_
# 38	Andoain	Andoain	PROPN	np00000	_	36	obl	36:obl	ClusterId=CESS-CAST-AA-20000511-8193-s3.sn.91|ClusterType=Spec.location|MentionSpan=38
# 39	a	a	ADP	sps00	_	40	case	40:case	_
# 40	José	José	PROPN	np00000	_	36	obj	36:obj	MWE=José_Luis_López_de_Lacalle|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-c12|ClusterType=Spec.person|MentionSpan=40-44
# 41	Luis	Luis	PROPN	_	_	40	flat	40:flat	_
# 42	López	López	PROPN	_	_	40	flat	40:flat	_
# 43	de	de	ADP	_	_	44	case	44:case	_
# 44	Lacalle	Lacalle	PROPN	_	_	40	flat	40:flat	SpaceAfter=No
# 45	.	.	PUNCT	fp	PunctType=Peri	9	punct	9:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s4
# # text = El diputado socialista eludió referirse a más detalles de este intento de atentado, pero sí admitió que uno de sus escoltas reconoció en fotografías entre los sospechosos a un presunto miembro de ETA.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	_
# 2	diputado	diputado	NOUN	ncms000	Gender=Masc|Number=Sing	4	nsubj	4:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=1-3|MentionMisc=CorefType:ident
# 3	socialista	socialista	ADJ	aq0cs0	Number=Sing	2	amod	2:amod	_
# 4	eludió	eludir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 5-6	referirse	_	_	_	_	_	_	_	_
# 5	referir	referir	VERB	vmn0000	VerbForm=Inf	4	xcomp	4:xcomp	_
# 6	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	5	expl:pv	5:expl:pv	_
# 7	a	a	ADP	sps00	_	9	case	9:case	_
# 8	más	más	ADV	rg	Degree=Cmp	9	advmod	9:advmod	_
# 9	detalles	detalle	NOUN	ncmp000	Gender=Masc|Number=Plur	5	obj	5:obj	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.19|ClusterType=Gen|MentionSpan=8-14
# 10	de	de	ADP	sps00	_	12	case	12:case	_
# 11	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	12	det	12:det	_
# 12	intento	intento	NOUN	ncms000	Gender=Masc|Number=Sing	9	nmod	9:nmod	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=11-14|MentionMisc=CorefType:ident
# 13	de	de	ADP	sps00	_	14	case	14:case	_
# 14	atentado	atentado	NOUN	ncms000	Gender=Masc|Number=Sing	12	nmod	12:nmod	SpaceAfter=No
# 15	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 16	pero	pero	CCONJ	cc	_	18	cc	18:cc	_
# 16.1	_	_	PRON	p	_	_	_	18:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=16.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 17	sí	sí	INTJ	rg	_	18	advcl	18:advcl	_
# 18	admitió	admitir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	4	conj	4:conj	_
# 19	que	que	SCONJ	cs	_	24	mark	24:mark	_
# 20	uno	uno	PRON	pi0ms000	Gender=Masc|Number=Sing|PronType=Ind	24	nsubj	24:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.51|ClusterType=Gen|MentionSpan=20-23
# 21	de	de	ADP	sps00	_	23	case	23:case	_
# 22	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	23	det	23:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=22|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 23	escoltas	escolta	NOUN	nccp000	Number=Plur	20	nmod	20:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.57|ClusterType=Gen|MentionSpan=22-23
# 24	reconoció	reconocer	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	18	ccomp	18:ccomp	_
# 25	en	en	ADP	sps00	_	26	case	26:case	_
# 26	fotografías	fotografía	NOUN	ncfp000	Gender=Fem|Number=Plur	24	obl	24:obl	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.67|ClusterType=Gen|MentionSpan=26
# 27	entre	entre	ADP	sps00	_	29	case	29:case	_
# 28	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	29	det	29:det	_
# 29	sospechosos	sospechoso	NOUN	ncmp000	Gender=Masc|Number=Plur	24	obl	24:obl	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.73|ClusterType=Gen|MentionSpan=28-29|MentionMisc=HomoDD
# 30	a	a	ADP	sps00	_	33	case	33:case	_
# 31	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	33	det	33:det	_
# 32	presunto	presunto	ADJ	aq0ms0	Gender=Masc|Number=Sing	33	amod	33:amod	_
# 33	miembro	miembro	NOUN	ncms000	Gender=Masc|Number=Sing	24	obj	24:obj	ClusterId=CESS-CAST-AA-20000511-8193-s4.sn.81|ClusterType=Gen|MentionSpan=31-35
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	ETA	ETA	PROPN	np00000	_	33	nmod	33:nmod	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c2|ClusterType=Spec.organization|MentionSpan=35|MentionMisc=CorefType:ident
# 36	.	.	PUNCT	fp	PunctType=Peri	4	punct	4:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s5
# # text = Insistió en que quien haya filtrado esta noticia ha actuado "imprudentemente" y dijo que alrededor de la vida de los políticos en el País Vasco hay personas "que sufren con este tipo de informaciones".
# 0.1	_	_	PRON	p	_	_	_	1:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=0.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 1	Insistió	insistir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 2	en	en	ADP	sps00	_	10	mark	10:mark	_
# 3	que	que	SCONJ	cs	_	10	mark	10:mark	_
# 4	quien	quien	PRON	pr0cs000	Number=Sing|PronType=Int,Rel	6	nsubj	6:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-s5.relatiu.13|ClusterType=Gen|MentionSpan=4
# 5	haya	haber	AUX	vasp3s0	Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	aux	6:aux	_
# 6	filtrado	filtrar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	10	csubj	10:csubj	_
# 7	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	8	det	8:det	_
# 8	noticia	noticia	NOUN	ncfs000	Gender=Fem|Number=Sing	6	obj	6:obj	ClusterId=CESS-CAST-AA-20000511-8193-c5|ClusterType=Gen|MentionSpan=7-8|MentionMisc=CorefType:ident
# 9	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	10	aux	10:aux	_
# 10	actuado	actuar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	1	ccomp	1:ccomp	_
# 11	"	"	PUNCT	fe	PunctType=Quot	12	punct	12:punct	SpaceAfter=No
# 12	imprudentemente	imprudentemente	ADV	rg	_	10	advmod	10:advmod	SpaceAfter=No
# 13	"	"	PUNCT	fe	PunctType=Quot	12	punct	12:punct	_
# 14	y	y	CCONJ	cc	_	15	cc	15:cc	_
# 14.1	_	_	PRON	p	_	_	_	15:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=14.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 15	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	1	conj	1:conj	_
# 16	que	que	SCONJ	cs	_	28	mark	28:mark	_
# 17	alrededor	alrededor	ADV	rg	_	28	advmod	28:advmod	MWE=alrededor_de|MWEPOS=ADV
# 18	de	de	ADP	_	_	17	fixed	17:fixed	_
# 19	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	20:det	_
# 20	vida	vida	NOUN	ncfs000	Gender=Fem|Number=Sing	17	obl	17:obl	ClusterId=CESS-CAST-AA-20000511-8193-s5.sn.43|ClusterType=Gen|MentionSpan=19-27|MentionMisc=HomoDD
# 21	de	de	ADP	sps00	_	23	case	23:case	_
# 22	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	23	det	23:det	_
# 23	políticos	político	NOUN	ncmp000	Gender=Masc|Number=Plur	20	nmod	20:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s5.sn.51|ClusterType=Gen|MentionSpan=22-23|MentionMisc=HomoDD
# 24	en	en	ADP	sps00	_	26	case	26:case	_
# 25	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	26:det	_
# 26	País	País	PROPN	np00000	_	20	nmod	20:nmod	MWE=País_Vasco|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-c6|ClusterType=Spec.location|MentionSpan=25-27|MentionMisc=CorefType:ident
# 27	Vasco	Vasco	PROPN	_	_	26	flat	26:flat	_
# 28	hay	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	15	ccomp	15:ccomp	_
# 29	personas	persona	NOUN	ncfp000	Gender=Fem|Number=Plur	28	obj	28:obj	ClusterId=CESS-CAST-AA-20000511-8193-c7|ClusterType=Gen|MentionSpan=29-38
# 30	"	"	PUNCT	fe	PunctType=Quot	32	punct	32:punct	SpaceAfter=No
# 31	que	que	PRON	pr0cn000	PronType=Int,Rel	32	nsubj	32:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c7|ClusterType=Gen|MentionSpan=31|MentionMisc=CorefType:ident
# 32	sufren	sufrir	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	29	acl	29:acl	_
# 33	con	con	ADP	sps00	_	35	case	35:case	_
# 34	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	35	det	35:det	_
# 35	tipo	tipo	NOUN	ncms000	Gender=Masc|Number=Sing	32	obl	32:obl	ClusterId=CESS-CAST-AA-20000511-8193-c5|ClusterType=Gen|MentionSpan=34-37|MentionMisc=CorefType:ident
# 36	de	de	ADP	sps00	_	37	case	37:case	_
# 37	informaciones	información	NOUN	ncfp000	Gender=Fem|Number=Plur	35	nmod	35:nmod	SpaceAfter=No
# 38	"	"	PUNCT	fe	PunctType=Quot	32	punct	32:punct	SpaceAfter=No
# 39	.	.	PUNCT	fp	PunctType=Peri	1	punct	1:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s6
# # text = Benegas, en declaraciones a los medios de comunicación en el Congreso, aseguró que desconoce de dónde ha partido la noticia, y explicó que desde el año 1977 ha tenido "más problemas" pero manifestó que no le gusta "hacer gala de lo que me ha ocurrido, porque entra dentro de mi trabajo y de mi lucha política por la libertad y por la paz".
# 1	Benegas	Benegas	PROPN	np00000	_	14	nsubj	14:nsubj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=1|MentionMisc=CorefType:ident
# 2	,	,	PUNCT	fc	PunctType=Comm	4	punct	4:punct	_
# 3	en	en	ADP	sps00	_	4	case	4:case	_
# 4	declaraciones	declaración	NOUN	ncfp000	Gender=Fem|Number=Plur	14	obl	14:obl	ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.10|ClusterType=Gen|MentionSpan=4-12
# 5	a	a	ADP	sps00	_	7	case	7:case	_
# 6	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	7	det	7:det	_
# 7	medios	medio	NOUN	ncmp000	Gender=Masc|Number=Plur	4	nmod	4:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.16|ClusterType=Gen|MentionSpan=6-9|MentionMisc=HomoDD
# 8	de	de	ADP	sps00	_	9	case	9:case	_
# 9	comunicación	comunicación	NOUN	ncfs000	Gender=Fem|Number=Sing	7	nmod	7:nmod	_
# 10	en	en	ADP	sps00	_	12	case	12:case	_
# 11	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	12:det	_
# 12	Congreso	Congreso	PROPN	np00000	_	4	nmod	4:nmod	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.30|ClusterType=Spec.organization|MentionSpan=11-12
# 13	,	,	PUNCT	fc	PunctType=Comm	4	punct	4:punct	_
# 14	aseguró	asegurar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 15	que	que	SCONJ	cs	_	16	mark	16:mark	_
# 15.1	_	_	PRON	p	_	_	_	16:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=15.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 16	desconoce	desconocer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	14	ccomp	14:ccomp	_
# 17	de	de	ADP	sps00	_	18	case	18:case	_
# 18	dónde	dónde	PRON	pt000000	PronType=Ind	20	obl	20:obl	ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.48|ClusterType=Gen|MentionSpan=18
# 19	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	20	aux	20:aux	_
# 20	partido	partir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	16	ccomp	16:ccomp	_
# 21	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	22	det	22:det	_
# 22	noticia	noticia	NOUN	ncfs000	Gender=Fem|Number=Sing	20	nsubj	20:nsubj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c5|ClusterType=Gen|MentionSpan=21-22|MentionMisc=CorefType:ident
# 23	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	_
# 24	y	y	CCONJ	cc	_	25	cc	25:cc	_
# 24.1	_	_	PRON	p	_	_	_	25:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=24.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 25	explicó	explicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	14	conj	14:conj	_
# 26	que	que	SCONJ	cs	_	32	mark	32:mark	_
# 27	desde	desde	ADP	sps00	_	29	case	29:case	_
# 28	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 29	año	año	NOUN	_	_	32	obl	32:obl	MWE=año_1977|MWEPOS=NOUN|ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.73|ClusterType=Spec.date|MentionSpan=28-30
# 30	1977	1977	NUM	_	NumForm=Digit|NumType=Card	29	compound	29:compound	_
# 30.1	_	_	PRON	p	_	_	_	32:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=30.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 31	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	32	aux	32:aux	_
# 32	tenido	tener	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	25	ccomp	25:ccomp	_
# 33	"	"	PUNCT	fe	PunctType=Quot	35	punct	35:punct	SpaceAfter=No
# 34	más	más	ADV	rg	Degree=Cmp	35	advmod	35:advmod	_
# 35	problemas	problema	NOUN	ncmp000	Gender=Masc|Number=Plur	32	obj	32:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.82|ClusterType=Gen|MentionSpan=33-36
# 36	"	"	PUNCT	fe	PunctType=Quot	35	punct	35:punct	_
# 37	pero	pero	CCONJ	cc	_	38	cc	38:cc	_
# 37.1	_	_	PRON	p	_	_	_	38:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=37.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 38	manifestó	manifestar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	25	conj	25:conj	_
# 39	que	que	SCONJ	cs	_	42	mark	42:mark	_
# 40	no	no	ADV	rn	Polarity=Neg	42	advmod	42:advmod	_
# 41	le	él	PRON	pp3csd00	Case=Dat|Number=Sing|Person=3|PronType=Prs	42	obj	42:obj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=41|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 42	gusta	gustar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	38	ccomp	38:ccomp	_
# 43	"	"	PUNCT	fe	PunctType=Quot	44	punct	44:punct	SpaceAfter=No
# 44	hacer	hacer	VERB	vmn0000	VerbForm=Inf	42	csubj	42:csubj	MWE=hacer_gala|MWEPOS=VERB
# 45	gala	gala	NOUN	_	Gender=Fem|Number=Sing	44	compound	44:compound	_
# 46	de	de	ADP	sps00	_	51	mark	51:mark	_
# 47	lo	él	PRON	da0ns0	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	51	det	51:det	_
# 48	que	que	PRON	pr0cn000	PronType=Int,Rel	51	nsubj	51:nsubj	_
# 49	me	yo	PRON	pp1cs000	Case=Dat|Number=Sing|Person=1|PrepCase=Npr|PronType=Prs	51	iobj	51:iobj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=49|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 50	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	51	aux	51:aux	_
# 51	ocurrido	ocurrir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	44	ccomp	44:ccomp	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=47-51|MentionMisc=CorefType:ident
# 52	,	,	PUNCT	fc	PunctType=Comm	44	punct	44:punct	_
# 53	porque	porque	SCONJ	cs	_	54	mark	54:mark	_
# 53.1	_	_	PRON	p	_	_	_	54:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=53.1|MentionMisc=CorefType:ident
# 54	entra	entrar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	42	advcl	42:advcl	_
# 55	dentro	dentro	ADV	sps00	_	58	case	58:case	MWE=dentro_de|MWEPOS=ADP
# 56	de	de	ADP	_	_	55	fixed	55:fixed	_
# 57	mi	mi	DET	dp1css	Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	58	det	58:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=57|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 58	trabajo	trabajo	NOUN	ncms000	Gender=Masc|Number=Sing	54	obl	54:obl	ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.136|ClusterType=Gen|MentionSpan=57-58
# 59	y	y	CCONJ	cc	_	62	cc	62:cc	_
# 60	de	de	ADP	sps00	_	62	case	62:case	_
# 61	mi	mi	DET	dp1css	Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	62	det	62:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=61|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 62	lucha	lucha	NOUN	ncfs000	Gender=Fem|Number=Sing	58	conj	58:conj	ClusterId=CESS-CAST-AA-20000511-8193-s6.sn.146|ClusterType=Gen|MentionSpan=61-70
# 63	política	política	ADJ	aq0fs0	Gender=Fem|Number=Sing	62	amod	62:amod	_
# 64	por	por	ADP	sps00	_	66	case	66:case	_
# 65	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	66	det	66:det	_
# 66	libertad	libertad	NOUN	ncfs000	Gender=Fem|Number=Sing	62	nmod	62:nmod	ClusterId=CESS-CAST-AA-20000511-8193-c9|ClusterType=Gen|MentionSpan=65-66|MentionMisc=HomoDD,CorefType:ident
# 67	y	y	CCONJ	cc	_	70	cc	70:cc	_
# 68	por	por	ADP	sps00	_	70	case	70:case	_
# 69	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	70	det	70:det	_
# 70	paz	paz	NOUN	ncfs000	Gender=Fem|Number=Sing	66	conj	66:conj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c10|ClusterType=Gen|MentionSpan=69-70|MentionMisc=HomoDD,CorefType:ident
# 71	"	"	PUNCT	fe	PunctType=Quot	42	punct	42:punct	SpaceAfter=No
# 72	.	.	PUNCT	fp	PunctType=Peri	14	punct	14:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s7
# # text = "He tenido que enterrar ya a mucha gente, a amigos y compañeros, como para hacer gala de haber tenido un incidente", dijo Benegas, quien explicó que se limitó a poner el hecho en conocimiento del subdelegado del Gobierno en Guipúzcoa y que su escolta dio parte de lo ocurrido a sus superiores.
# 1	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	SpaceAfter=No
# 1.1	_	_	PRON	p	_	_	_	3:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=1.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 2	He	haber	AUX	vaip1s0	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	5	aux	5:aux	_
# 3	tenido	tener	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	27	ccomp	27:ccomp	_
# 4	que	que	SCONJ	cs	_	5	cc	5:cc	_
# 5	enterrar	enterrar	VERB	vmn0000	VerbForm=Inf	3	conj	3:conj	_
# 6	ya	ya	ADV	rg	_	5	advmod	5:advmod	_
# 7	a	a	ADP	sps00	_	9	case	9:case	_
# 8	mucha	mucho	DET	di0fs0	Gender=Fem|Number=Sing|NumType=Card|PronType=Ind	9	det	9:det	_
# 9	gente	gente	NOUN	ncfs000	Gender=Fem|Number=Sing	5	obj	5:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.17|ClusterType=Gen|MentionSpan=8-15
# 10	,	,	PUNCT	fc	PunctType=Comm	12	punct	12:punct	_
# 11	a	a	ADP	sps00	_	12	case	12:case	_
# 12	amigos	amigo	NOUN	ncmp000	Gender=Masc|Number=Plur	9	nmod	9:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s7.grup.nom.28|ClusterType=Gen|MentionSpan=12
# 13	y	y	CCONJ	cc	_	14	cc	14:cc	_
# 14	compañeros	compañero	NOUN	ncmp000	Gender=Masc|Number=Plur	12	conj	12:conj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s7.grup.nom.32|ClusterType=Gen|MentionSpan=14
# 15	,	,	PUNCT	fc	PunctType=Comm	12	punct	12:punct	_
# 16	como	como	SCONJ	cs	_	18	mark	18:mark	MWE=como_para|MWEPOS=SCONJ
# 17	para	para	ADP	_	_	16	fixed	16:fixed	_
# 18	hacer	hacer	VERB	vmn0000	VerbForm=Inf	5	advcl	5:advcl	MWE=hacer_gala|MWEPOS=VERB
# 19	gala	gala	NOUN	_	Gender=Fem|Number=Sing	18	compound	18:compound	_
# 20	de	de	ADP	sps00	_	22	mark	22:mark	_
# 21	haber	haber	AUX	van0000	VerbForm=Inf	22	aux	22:aux	_
# 22	tenido	tener	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	18	ccomp	18:ccomp	_
# 23	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	24	det	24:det	_
# 24	incidente	incidente	NOUN	nccs000	Number=Sing	22	obj	22:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=23-24|MentionMisc=CorefType:ident
# 25	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	SpaceAfter=No
# 26	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 27	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 28	Benegas	Benegas	PROPN	np00000	_	27	nsubj	27:nsubj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=28-60|MentionMisc=CorefType:ident
# 29	,	,	PUNCT	fc	PunctType=Comm	31	punct	31:punct	_
# 30	quien	quien	PRON	pr0cs000	Number=Sing|PronType=Int,Rel	31	nsubj	31:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=30|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 31	explicó	explicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	28	acl	28:acl	_
# 32	que	que	SCONJ	cs	_	34	mark	34:mark	_
# 32.1	_	_	PRON	p	_	_	_	34:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=32.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 33	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	34	expl:pv	34:expl:pv	_
# 34	limitó	limitar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	31	ccomp	31:ccomp	_
# 35	a	a	ADP	sps00	_	36	mark	36:mark	_
# 36	poner	poner	VERB	vmn0000	VerbForm=Inf	34	xcomp	34:xcomp	_
# 37	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	_
# 38	hecho	hecho	NOUN	ncms000	Gender=Masc|Number=Sing	36	obj	36:obj	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=37-38|MentionMisc=CorefType:ident
# 39	en	en	ADP	sps00	_	40	case	40:case	_
# 40	conocimiento	conocimiento	NOUN	ncms000	Gender=Masc|Number=Sing	36	obl	36:obl	ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.89|ClusterType=Gen|MentionSpan=40-48
# 41-42	del	_	_	_	_	_	_	_	_
# 41	de	de	ADP	spcms	_	43	case	43:case	_
# 42	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	43	det	43:det	_
# 43	subdelegado	subdelegado	NOUN	ncms000	Gender=Masc|Number=Sing	40	nmod	40:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.95|ClusterType=Spec.person|MentionSpan=43-48
# 44-45	del	_	_	_	_	_	_	_	_
# 44	de	de	ADP	spcms	_	46	case	46:case	_
# 45	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	46	det	46:det	_
# 46	Gobierno	Gobierno	PROPN	np00000	_	43	nmod	43:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.101|ClusterType=Spec.organization|MentionSpan=46
# 47	en	en	ADP	sps00	_	48	case	48:case	_
# 48	Guipúzcoa	Guipúzcoa	PROPN	np00000	_	43	nmod	43:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.107|ClusterType=Spec.location|MentionSpan=48
# 49	y	y	CCONJ	cc	_	53	cc	53:cc	_
# 50	que	que	SCONJ	cs	_	53	mark	53:mark	_
# 51	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	52	det	52:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=51|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 52	escolta	escolta	NOUN	nccs000	Number=Sing	53	nsubj	53:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c27|ClusterType=Gen|MentionSpan=51-52
# 53	dio	dar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	34	conj	34:conj	MWE=dio_parte|MWEPOS=VERB
# 54	parte	parte	NOUN	_	Number=Sing	53	compound	53:compound	_
# 55	de	de	ADP	sps00	_	57	case	57:case	_
# 56	lo	él	PRON	da0ns0	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	57	det	57:det	_
# 57	ocurrido	ocurrido	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	53	obj	53:obj	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=56-57|MentionMisc=CorefType:ident
# 58	a	a	ADP	sps00	_	60	case	60:case	_
# 59	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	60	det	60:det	ClusterId=CESS-CAST-AA-20000511-8193-c27|ClusterType=Gen|MentionSpan=59|MentionMisc=CorefType:ident
# 60	superiores	superior	NOUN	ncmp000	Gender=Masc|Number=Plur	53	obj	53:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s7.sn.135|ClusterType=Gen|MentionSpan=59-60
# 61	.	.	PUNCT	fp	PunctType=Peri	27	punct	27:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s8
# # text = El diputado del PSE, quien aseguró que durante las últimas horas ha recibido muchas llamadas, precisó que el incidente ocurrió a las 10:00 horas.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	_
# 2	diputado	diputado	NOUN	ncms000	Gender=Masc|Number=Sing	19	nsubj	19:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=1-18|MentionMisc=CorefType:ident
# 3-4	del	_	_	_	_	_	_	_	_
# 3	de	de	ADP	spcms	_	5	case	5:case	_
# 4	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	_
# 5	PSE	PSE	PROPN	np00000	_	2	nmod	2:nmod	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s8.sn.10|ClusterType=Spec.organization|MentionSpan=5
# 6	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	_
# 7	quien	quien	PRON	pr0cs000	Number=Sing|PronType=Int,Rel	8	nsubj	8:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=7|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 8	aseguró	asegurar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	2	acl	2:acl	_
# 9	que	que	SCONJ	cs	_	15	mark	15:mark	_
# 10	durante	durante	ADP	sps00	_	13	case	13:case	_
# 11	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	13	det	13:det	_
# 12	últimas	último	ADJ	ao0fp0	Gender=Fem|Number=Plur|NumType=Ord	13	amod	13:amod	_
# 13	horas	hora	NOUN	ncfp000	Gender=Fem|Number=Plur	15	obl	15:obl	ClusterId=CESS-CAST-AA-20000511-8193-s8.sn.25|ClusterType=Gen|MentionSpan=11-13|MentionMisc=HomoDD
# 13.1	_	_	PRON	p	_	_	_	15:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=13.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 14	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	15	aux	15:aux	_
# 15	recibido	recibir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	8	ccomp	8:ccomp	_
# 16	muchas	mucho	DET	di0fp0	Gender=Fem|Number=Plur|NumType=Card|PronType=Ind	17	det	17:det	_
# 17	llamadas	llamada	NOUN	ncfp000	Gender=Fem|Number=Plur	15	obj	15:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s8.sn.37|ClusterType=Gen|MentionSpan=16-17
# 18	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	_
# 19	precisó	precisar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 20	que	que	SCONJ	cs	_	23	mark	23:mark	_
# 21	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	22:det	_
# 22	incidente	incidente	NOUN	nccs000	Number=Sing	23	nsubj	23:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c3|ClusterType=Gen|MentionSpan=21-22|MentionMisc=CorefType:ident
# 23	ocurrió	ocurrir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	19	ccomp	19:ccomp	_
# 24	a	a	ADP	sps00	_	26	case	26:case	_
# 25	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	26	det	26:det	_
# 26	10:00	10:00	NUM	_	NumForm=Digit|NumType=Card	23	obl	23:obl	MWE=10:00_horas|MWEPOS=NOUN|ClusterId=CESS-CAST-AA-20000511-8193-s8.sn.58|ClusterType=Spec.date|MentionSpan=25-27
# 27	horas	horas	NOUN	_	_	26	compound	26:compound	SpaceAfter=No
# 28	.	.	PUNCT	fp	PunctType=Peri	19	punct	19:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s9
# # text = Estimó que es "evidente" que durante los últimos meses el PSOE siendo uno de los objetivos de la violencia en el País Vasco, recordó los asesinatos de Fernando Buesa y de José Luis López de Lacalle, y observó que además de estos actos los concejales sufren la "violencia urbana" contra sus casas o los locales que regentan, así como amenazas.
# 0.1	_	_	PRON	p	_	_	_	1:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=0.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 1	Estimó	estimar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 2	que	que	SCONJ	cs	_	5	mark	5:mark	_
# 3	es	ser	AUX	vsip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	cop	5:cop	_
# 4	"	"	PUNCT	fe	PunctType=Quot	5	punct	5:punct	SpaceAfter=No
# 5	evidente	evidente	ADJ	aq0cs0	Number=Sing	1	ccomp	1:ccomp	SpaceAfter=No
# 6	"	"	PUNCT	fe	PunctType=Quot	5	punct	5:punct	_
# 7	que	que	SCONJ	cs	_	15	mark	15:mark	_
# 8	durante	durante	ADP	sps00	_	11	case	11:case	_
# 9	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	11	det	11:det	_
# 10	últimos	último	ADJ	ao0mp0	Gender=Masc|Number=Plur|NumType=Ord	11	amod	11:amod	_
# 11	meses	mes	NOUN	ncmp000	Gender=Masc|Number=Plur	15	obl	15:obl	ClusterId=CESS-CAST-AA-20000511-8193-s9.sn.22|ClusterType=Gen|MentionSpan=9-11|MentionMisc=HomoDD
# 12	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	13:det	_
# 13	PSOE	PSOE	PROPN	np00000	_	15	obj	15:obj	ClusterId=CESS-CAST-AA-20000511-8193-c11|ClusterType=Spec.organization|MentionSpan=12-13
# 14	siendo	ser	AUX	vsg0000	VerbForm=Ger	15	cop	15:cop	_
# 15	uno	uno	PRON	pi0ms000	Gender=Masc|Number=Sing|PronType=Ind	5	csubj	5:csubj	ClusterId=CESS-CAST-AA-20000511-8193-c11|ClusterType=Spec.organization|MentionSpan=15-25|MentionMisc=ClusterTypeMismatch::Spec.organization,CorefType:pred.indefinit
# 16	de	de	ADP	sps00	_	18	case	18:case	_
# 17	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	18	det	18:det	_
# 18	objetivos	objetivo	NOUN	ncmp000	Gender=Masc|Number=Plur	15	nmod	15:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s9.sn.44|ClusterType=Gen|MentionSpan=17-25|MentionMisc=HomoDD
# 19	de	de	ADP	sps00	_	21	case	21:case	_
# 20	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	21	det	21:det	_
# 21	violencia	violencia	NOUN	ncfs000	Gender=Fem|Number=Sing	18	nmod	18:nmod	ClusterId=CESS-CAST-AA-20000511-8193-c19|ClusterType=Gen|MentionSpan=20-21|MentionMisc=HomoDD
# 22	en	en	ADP	sps00	_	24	case	24:case	_
# 23	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	24	det	24:det	_
# 24	País	País	PROPN	np00000	_	18	nmod	18:nmod	MWE=País_Vasco|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-c6|ClusterType=Spec.location|MentionSpan=23-25|MentionMisc=CorefType:ident
# 25	Vasco	Vasco	PROPN	_	_	24	flat	24:flat	SpaceAfter=No
# 26	,	,	PUNCT	fc	PunctType=Comm	27	punct	27:punct	_
# 26.1	_	_	PRON	p	_	_	_	27:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=26.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 27	recordó	recordar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	1	advcl	1:advcl	_
# 28	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	29	det	29:det	_
# 29	asesinatos	asesinato	NOUN	ncmp000	Gender=Masc|Number=Plur	27	obj	27:obj	ClusterId=CESS-CAST-AA-20000511-8193-c13|ClusterType=Gen|MentionSpan=28-39|MentionMisc=HomoDD
# 30	de	de	ADP	sps00	_	31	case	31:case	_
# 31	Fernando	Fernando	PROPN	np00000	_	29	nmod	29:nmod	MWE=Fernando_Buesa|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-s9.sn.79|ClusterType=Spec.person|MentionSpan=31-32
# 32	Buesa	Buesa	PROPN	_	_	31	flat	31:flat	_
# 33	y	y	CCONJ	cc	_	35	cc	35:cc	_
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	José	José	PROPN	np00000	_	31	conj	31:conj	MWE=José_Luis_López_de_Lacalle|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-c12|ClusterType=Spec.person|MentionSpan=35-39|MentionMisc=CorefType:ident
# 36	Luis	Luis	PROPN	_	_	35	flat	35:flat	_
# 37	López	López	PROPN	_	_	35	flat	35:flat	_
# 38	de	de	ADP	_	_	39	case	39:case	_
# 39	Lacalle	Lacalle	PROPN	_	_	35	flat	35:flat	SpaceAfter=No
# 40	,	,	PUNCT	fc	PunctType=Comm	27	punct	27:punct	_
# 41	y	y	CCONJ	cc	_	42	cc	42:cc	_
# 41.1	_	_	PRON	p	_	_	_	42:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=41.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 42	observó	observar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	1	conj	1:conj	_
# 43	que	que	SCONJ	cs	_	50	mark	50:mark	_
# 44	además	además	ADV	sps00	_	47	case	47:case	MWE=además_de|MWEPOS=ADP
# 45	de	de	ADP	_	_	44	fixed	44:fixed	_
# 46	estos	este	DET	dd0mp0	Gender=Masc|Number=Plur|PronType=Dem	47	det	47:det	_
# 47	actos	acto	NOUN	ncmp000	Gender=Masc|Number=Plur	50	obl	50:obl	ClusterId=CESS-CAST-AA-20000511-8193-c13|ClusterType=Gen|MentionSpan=46-47|MentionMisc=CorefType:ident
# 48	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	49	det	49:det	_
# 49	concejales	concejal	NOUN	ncmp000	Gender=Masc|Number=Plur	50	nsubj	50:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c15|ClusterType=Gen|MentionSpan=48-49|MentionMisc=HomoDD
# 50	sufren	sufrir	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	42	ccomp	42:ccomp	_
# 51	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	53	det	53:det	_
# 52	"	"	PUNCT	fe	PunctType=Quot	51	punct	51:punct	SpaceAfter=No
# 53	violencia	violencia	NOUN	ncfs000	Gender=Fem|Number=Sing	50	obj	50:obj	ClusterId[1]=CESS-CAST-AA-20000511-8193-s9.sn.115|ClusterType[1]=Gen|MentionSpan[1]=51-67|ClusterId[2]=CESS-CAST-AA-20000511-8193-s9.sn.116|ClusterType[2]=Gen|MentionSpan[2]=51-64|MentionMisc[2]=HomoDD
# 54	urbana	urbano	ADJ	aq0fs0	Gender=Fem|Number=Sing	53	amod	53:amod	SpaceAfter=No
# 55	"	"	PUNCT	fe	PunctType=Quot	58	punct	58:punct	_
# 56	contra	contra	ADP	sps00	_	58	case	58:case	_
# 57	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	58	det	58:det	ClusterId=CESS-CAST-AA-20000511-8193-c15|ClusterType=Gen|MentionSpan=57|MentionMisc=CorefType:ident
# 58	casas	casa	NOUN	ncfp000	Gender=Fem|Number=Plur	53	nmod	53:nmod	ClusterId[1]=CESS-CAST-AA-20000511-8193-s9.sn.129|ClusterType[1]=Gen|MentionSpan[1]=57-63|ClusterId[2]=CESS-CAST-AA-20000511-8193-s9.sn.130|ClusterType[2]=Gen|MentionSpan[2]=57-58
# 59	o	o	CCONJ	cc	_	61	cc	61:cc	_
# 60	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	61	det	61:det	_
# 61	locales	local	NOUN	ncmp000	Gender=Masc|Number=Plur	58	conj	58:conj	ClusterId=CESS-CAST-AA-20000511-8193-c14|ClusterType=Gen|MentionSpan=60-63|MentionMisc=HomoDD
# 62	que	que	PRON	pr0cn000	PronType=Int,Rel	63	obj	63:obj	ClusterId=CESS-CAST-AA-20000511-8193-c14|ClusterType=Gen|MentionSpan=62|MentionMisc=CorefType:ident
# 62.1	_	_	PRON	p	_	_	_	63:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c15|ClusterType=Gen|MentionSpan=62.1|MentionMisc=CorefType:ident
# 63	regentan	regentar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	61	acl	61:acl	SpaceAfter=No
# 64	,	,	PUNCT	fc	PunctType=Comm	67	punct	67:punct	_
# 65	así	así	ADV	cs	_	67	cc	67:cc	MWE=así_como|MWEPOS=SCONJ
# 66	como	como	SCONJ	_	_	65	fixed	65:fixed	_
# 67	amenazas	amenaza	NOUN	ncfp000	Gender=Fem|Number=Plur	53	conj	53:conj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s9.sn.151|ClusterType=Gen|MentionSpan=67
# 68	.	.	PUNCT	fp	PunctType=Peri	1	punct	1:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s10
# # text = "Esta etapa nos está tocando a nosotros", dijo Benegas, quien manifestó que el PP sufrió una etapa "terrible" y que muchos ciudadanos ajenos a la política han sido también víctimas de la violencia terrorista.
# 1	"	"	PUNCT	fe	PunctType=Quot	6	punct	6:punct	SpaceAfter=No
# 2	Esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	3	det	3:det	_
# 3	etapa	etapa	NOUN	ncfs000	Gender=Fem|Number=Sing	6	nsubj	6:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.4|ClusterType=Gen|MentionSpan=2-3
# 4	nos	yo	PRON	pp1cp000	Case=Dat|Number=Plur|Person=1|PrepCase=Npr|PronType=Prs	6	iobj	6:iobj	ClusterId=CESS-CAST-AA-20000511-8193-c11|ClusterType=Spec.organization|MentionSpan=4|MentionMisc=ClusterTypeMismatch:Spec:Spec.organization,CorefType:ident
# 5	está	estar	AUX	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	aux	6:aux	_
# 6	tocando	tocar	VERB	vmg0000	VerbForm=Ger	11	ccomp	11:ccomp	_
# 7	a	a	ADP	sps00	_	8	case	8:case	_
# 8	nosotros	yo	PRON	pp1mp000	Case=Acc,Nom|Gender=Masc|Number=Plur|Person=1|PronType=Prs	6	obj	6:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c11|ClusterType=Spec.organization|MentionSpan=8|MentionMisc=ClusterTypeMismatch:Spec:Spec.organization,CorefType:ident
# 9	"	"	PUNCT	fe	PunctType=Quot	6	punct	6:punct	SpaceAfter=No
# 10	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	_
# 11	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 12	Benegas	Benegas	PROPN	np00000	_	11	nsubj	11:nsubj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=12-40|MentionMisc=CorefType:ident
# 13	,	,	PUNCT	fc	PunctType=Comm	15	punct	15:punct	_
# 14	quien	quien	PRON	pr0cs000	Number=Sing|PronType=Int,Rel	15	nsubj	15:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=14|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 15	manifestó	manifestar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	12	acl	12:acl	_
# 16	que	que	SCONJ	cs	_	19	mark	19:mark	_
# 17	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	18	det	18:det	_
# 18	PP	PP	PROPN	np00000	_	19	nsubj	19:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.39|ClusterType=Spec.organization|MentionSpan=17-18
# 19	sufrió	sufrir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	15	ccomp	15:ccomp	_
# 20	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	21	det	21:det	_
# 21	etapa	etapa	NOUN	ncfs000	Gender=Fem|Number=Sing	19	obj	19:obj	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.46|ClusterType=Gen|MentionSpan=20-24
# 22	"	"	PUNCT	fe	PunctType=Quot	23	punct	23:punct	SpaceAfter=No
# 23	terrible	terrible	ADJ	aq0cs0	Number=Sing	21	amod	21:amod	SpaceAfter=No
# 24	"	"	PUNCT	fe	PunctType=Quot	23	punct	23:punct	_
# 25	y	y	CCONJ	cc	_	36	cc	36:cc	_
# 26	que	que	SCONJ	cs	_	36	mark	36:mark	_
# 27	muchos	mucho	DET	di0mp0	Gender=Masc|Number=Plur|NumType=Card|PronType=Ind	28	det	28:det	_
# 28	ciudadanos	ciudadano	NOUN	ncmp000	Gender=Masc|Number=Plur	36	nsubj	36:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.61|ClusterType=Gen|MentionSpan=27-32
# 29	ajenos	ajeno	ADJ	aq0mp0	Gender=Masc|Number=Plur	28	amod	28:amod	_
# 30	a	a	ADP	sps00	_	32	case	32:case	_
# 31	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	32	det	32:det	_
# 32	política	política	NOUN	ncfs000	Gender=Fem|Number=Sing	29	nmod	29:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.72|ClusterType=Gen|MentionSpan=31-32|MentionMisc=HomoDD
# 33	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	36	aux	36:aux	_
# 34	sido	ser	AUX	vsp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	36	cop	36:cop	_
# 35	también	también	ADV	rg	_	36	advmod	36:advmod	_
# 36	víctimas	víctima	NOUN	ncfp000	Gender=Fem|Number=Plur	19	conj	19:conj	ClusterId=CESS-CAST-AA-20000511-8193-s10.sn.83|ClusterType=Gen|MentionSpan=36-40
# 37	de	de	ADP	sps00	_	39	case	39:case	_
# 38	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	39	det	39:det	_
# 39	violencia	violencia	NOUN	ncfs000	Gender=Fem|Number=Sing	36	nmod	36:nmod	ClusterId=CESS-CAST-AA-20000511-8193-c20|ClusterType=Gen|MentionSpan=38-40|MentionMisc=HomoDD
# 40	terrorista	terrorista	ADJ	aq0cs0	Number=Sing	39	amod	39:amod	SpaceAfter=No
# 41	.	.	PUNCT	fp	PunctType=Peri	11	punct	11:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s11
# # text = Al ser preguntado sobre si ha recibido llamadas del ministro del Interior y de representantes del Gobierno vasco, el diputado socialista aseguró que tiene "cantidad de llamadas que no ha podido atender".
# 1-2	Al	_	_	_	_	_	_	_	_
# 1	A	a	ADP	spcms	_	4	case	4:case	_
# 2	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	4	det	4:det	_
# 3	ser	ser	AUX	vsn0000	VerbForm=Inf	4	aux	4:aux	_
# 4	preguntado	preguntar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	27	advcl	27:advcl	_
# 5	sobre	sobre	ADP	sps00	_	8	mark	8:mark	_
# 6	si	si	SCONJ	cs	_	8	mark	8:mark	_
# 6.1	_	_	PRON	p	_	_	_	8:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=6.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 7	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	8	aux	8:aux	_
# 8	recibido	recibir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	4	ccomp	4:ccomp	_
# 9	llamadas	llamada	NOUN	ncfp000	Gender=Fem|Number=Plur	8	obj	8:obj	ClusterId=CESS-CAST-AA-20000511-8193-s11.sn.19|ClusterType=Gen|MentionSpan=9-22
# 10-11	del	_	_	_	_	_	_	_	_
# 10	de	de	ADP	spcms	_	12	case	12:case	_
# 11	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	12:det	_
# 12	ministro	ministro	NOUN	ncms000	Gender=Masc|Number=Sing	9	nmod	9:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s11.sn.26|ClusterType=Spec.person|MentionSpan=12-15
# 13-14	del	_	_	_	_	_	_	_	_
# 13	de	de	ADP	spcms	_	15	case	15:case	_
# 14	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	15:det	_
# 15	Interior	Interior	PROPN	np00000	_	12	nmod	12:nmod	ClusterId=CESS-CAST-AA-20000511-8193-s11.sn.32|ClusterType=Spec.organization|MentionSpan=15
# 16	y	y	CCONJ	cc	_	18	cc	18:cc	_
# 17	de	de	ADP	sps00	_	18	case	18:case	_
# 18	representantes	representante	NOUN	nccp000	Number=Plur	12	conj	12:conj	ClusterId=CESS-CAST-AA-20000511-8193-s11.sn.40|ClusterType=Gen|MentionSpan=18-22
# 19-20	del	_	_	_	_	_	_	_	_
# 19	de	de	ADP	spcms	_	21	case	21:case	_
# 20	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	21	det	21:det	_
# 21	Gobierno	Gobierno	PROPN	np00000	_	18	nmod	18:nmod	ClusterId=CESS-CAST-AA-20000511-8193-c24|ClusterType=Spec.organization|MentionSpan=21-22
# 22	vasco	vasco	ADJ	aq0ms0	Gender=Masc|Number=Sing	21	amod	21:amod	SpaceAfter=No
# 23	,	,	PUNCT	fc	PunctType=Comm	4	punct	4:punct	_
# 24	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	25	det	25:det	_
# 25	diputado	diputado	NOUN	ncms000	Gender=Masc|Number=Sing	27	nsubj	27:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=24-26|MentionMisc=CorefType:ident
# 26	socialista	socialista	ADJ	aq0cs0	Number=Sing	25	amod	25:amod	_
# 27	aseguró	asegurar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 28	que	que	SCONJ	cs	_	29	mark	29:mark	_
# 28.1	_	_	PRON	p	_	_	_	29:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=28.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 29	tiene	tener	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	27	ccomp	27:ccomp	_
# 30	"	"	PUNCT	fe	PunctType=Quot	33	punct	33:punct	SpaceAfter=No
# 31	cantidad	cantidad	ADJ	aq0cn0	_	33	amod	33:amod	MWE=cantidad_de|MWEPOS=ADJ
# 32	de	de	ADP	_	_	31	amod	31:amod	_
# 33	llamadas	llamada	NOUN	ncfp000	Gender=Fem|Number=Plur	29	obj	29:obj	ClusterId=CESS-CAST-AA-20000511-8193-c16|ClusterType=Gen|MentionSpan=30-39
# 34	que	que	PRON	pr0cn000	PronType=Int,Rel	38	obj	38:obj	ClusterId=CESS-CAST-AA-20000511-8193-c16|ClusterType=Gen|MentionSpan=34|MentionMisc=CorefType:ident
# 34.1	_	_	PRON	p	_	_	_	38:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=34.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 35	no	no	ADV	rn	Polarity=Neg	38	advmod	38:advmod	_
# 36	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	38	aux	38:aux	_
# 37	podido	poder	AUX	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	38	aux	38:aux	_
# 38	atender	atender	VERB	vmn0000	VerbForm=Inf	33	acl	33:acl	SpaceAfter=No
# 39	"	"	PUNCT	fe	PunctType=Quot	33	punct	33:punct	SpaceAfter=No
# 40	.	.	PUNCT	fp	PunctType=Peri	27	punct	27:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000511-8193-s12
# # text = Txiqui Benegas afirmó que se encuentra decidido a seguir luchando "por lo que lo he hecho toda mi vida, la paz y la libertad de mi pueblo", y reclamó, ante la "brutalidad terrorista", que se reconstruya la unidad democrática y de los partidos "que respetamos el derecho a la vida y a la libertad".
# 1	Txiqui	Txiqui	PROPN	np00000	_	3	nsubj	3:nsubj	MWE=Txiqui_Benegas|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=1-2|MentionMisc=CorefType:ident
# 2	Benegas	Benegas	PROPN	_	_	1	flat	1:flat	_
# 3	afirmó	afirmar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 4	que	que	SCONJ	cs	_	6	mark	6:mark	_
# 4.1	_	_	PRON	p	_	_	_	6:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=4.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 5	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	6	expl:pv	6:expl:pv	_
# 6	encuentra	encontrar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	3	ccomp	3:ccomp	_
# 7	decidido	decidido	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	6	xcomp	6:xcomp	_
# 8	a	a	ADP	sps00	_	9	mark	9:mark	_
# 9	seguir	seguir	VERB	vmn0000	VerbForm=Inf	7	ccomp	7:ccomp	_
# 10	luchando	luchar	VERB	vmg0000	VerbForm=Ger	9	xcomp	9:xcomp	_
# 11	"	"	PUNCT	fe	PunctType=Quot	17	punct	17:punct	SpaceAfter=No
# 12	por	por	ADP	sps00	_	17	mark	17:mark	_
# 13	lo	él	PRON	da0ns0	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	17	det	17:det	_
# 14	que	que	PRON	pr0cn000	PronType=Int,Rel	17	obl	17:obl	_
# 14.1	_	_	PRON	p	_	_	_	17:nsubj	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=14.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 15	lo	él	PRON	pp3msa00	Case=Acc|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	17	obj	17:obj	_
# 16	he	haber	AUX	vaip1s0	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	17	aux	17:aux	_
# 17	hecho	hacer	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	10	ccomp	10:ccomp	ClusterId=CESS-CAST-AA-20000511-8193-s12.sn.31|ClusterType=Gen|MentionSpan=13-29
# 18	toda	todo	DET	di0fs0	Gender=Fem|Number=Sing|PronType=Tot	19	det	19:det	_
# 19	mi	mi	DET	dp1css	Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	20	det	20:det	ClusterId=CESS-CAST-AA-20000511-8193-c1|ClusterType=Spec.person|MentionSpan=19|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 20	vida	vida	NOUN	ncfs000	Gender=Fem|Number=Sing	17	obl	17:obl	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000511-8193-s12.sn.45|ClusterType=Gen|MentionSpan=18-20
# 21	,	,	PUNCT	fc	PunctType=Comm	23	punct	23:punct	_
# 22	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	23	det	23:det	_
# 23	paz	paz	NOUN	ncfs000	Gender=Fem|Number=Sing	17	iobj	17:iobj	ClusterId=CESS-CAST-AA-20000511-8193-c10|ClusterType=Gen|MentionSpan=22-23|MentionMisc=HomoDD,CorefType:ident
# 24	y	y	CCONJ	cc	_	26	cc	26:cc	_
# ...
# 16	nosotros	yo	PRON	pp1mp000	Case=Acc,Nom|Gender=Masc|Number=Plur|Person=1|PronType=Prs	18	nsubj	18:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c29|ClusterType=Gen|MentionSpan=16
# 17	somos	ser	AUX	vsip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	18	cop	18:cop	_
# 18	extremeños	extremeño	ADJ	aq0mp0	Gender=Masc|Number=Plur	6	acl	6:acl	_
# 19	pero	pero	CCONJ	cc	_	21	cc	21:cc	_
# 19.1	_	_	PRON	p	_	_	_	21:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c29|ClusterType=Gen|MentionSpan=19.1|MentionMisc=CorefType:ident
# 20	no	no	ADV	rn	Polarity=Neg	21	advmod	21:advmod	_
# 21	necesitamos	necesitar	VERB	vmip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	18	conj	18:conj	_
# 22	pegatinas	pegatina	NOUN	ncfp000	Gender=Fem|Number=Plur	21	obj	21:obj	ClusterId=CESS-CAST-AA-20000923-19559-s12.sn.52|ClusterType=Gen|MentionSpan=22-28
# 23	en	en	ADP	sps00	_	25	case	25:case	_
# 24	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	25	det	25:det	_
# 25	coche	coche	NOUN	ncms000	Gender=Masc|Number=Sing	22	nmod	22:nmod	ClusterId=CESS-CAST-AA-20000923-19559-s12.sn.59|ClusterType=Gen|MentionSpan=24-25|MentionMisc=HomoDD
# 26	ni	ni	CCONJ	cc	_	27	cc	27:cc	_
# 27	apellidos	apellido	NOUN	ncmp000	Gender=Masc|Number=Plur	22	conj	22:conj	_
# 28	autonomistas	autonomista	ADJ	aq0cp0	Number=Plur	27	amod	27:amod	SpaceAfter=No
# 29	"	"	PUNCT	fe	PunctType=Quot	18	punct	18:punct	SpaceAfter=No
# 30	.	.	PUNCT	fp	PunctType=Peri	4	punct	4:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000923-19559-s13
# # text = "Somos extremeños, somos españoles y somos europeos y para mí es bastante y no necesito más", subrayó.
# 1	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	SpaceAfter=No
# 1.1	_	_	PRON	p	_	_	_	2:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c29|ClusterType=Gen|MentionSpan=1.1|MentionMisc=CorefType:ident
# 2	Somos	ser	AUX	vsip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	3	cop	3:cop	ClusterId=CESS-CAST-AA-20000923-19559-c30|ClusterType=_|MentionSpan=1.1-9
# 3	extremeños	extremeño	ADJ	aq0mp0	Gender=Masc|Number=Plur	21	ccomp	21:ccomp	SpaceAfter=No
# 4	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	_
# 4.1	_	_	PRON	p	_	_	_	5:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c29|ClusterType=Gen|MentionSpan=4.1|MentionMisc=CorefType:ident
# 5	somos	ser	AUX	vsip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	6	cop	6:cop	_
# 6	españoles	español	ADJ	aq0mp0	Gender=Masc|Number=Plur	3	advcl	3:advcl	_
# 7	y	y	CCONJ	cc	_	9	cc	9:cc	_
# 7.1	_	_	PRON	p	_	_	_	8:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c29|ClusterType=Gen|MentionSpan=7.1|MentionMisc=CorefType:ident
# 8	somos	ser	AUX	vsip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	9	cop	9:cop	_
# 9	europeos	europeo	ADJ	aq0mp0	Gender=Masc|Number=Plur	3	conj	3:conj	_
# 10	y	y	CCONJ	cc	_	14	cc	14:cc	_
# 11	para	para	ADP	sps00	_	12	case	12:case	_
# 12	mí	yo	PRON	pp1cso00	Case=Acc|Number=Sing|Person=1|PrepCase=Pre|PronType=Prs	14	obl	14:obl	ClusterId=CESS-CAST-AA-20000923-19559-c1|ClusterType=Spec.person|MentionSpan=12|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 12.1	_	_	PRON	p	_	_	_	13:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c30|ClusterType=_|MentionSpan=12.1|MentionMisc=ClusterTypeMismatch:Gen:,CorefType:dx.token
# 13	es	ser	AUX	vsip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	14	cop	14:cop	_
# 14	bastante	bastante	ADV	rg	_	3	conj	3:conj	_
# 15	y	y	CCONJ	cc	_	17	cc	17:cc	_
# 15.1	_	_	PRON	p	_	_	_	17:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c1|ClusterType=Spec.person|MentionSpan=15.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 16	no	no	ADV	rn	Polarity=Neg	17	advmod	17:advmod	_
# 17	necesito	necesitar	VERB	vmip1s0	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	14	conj	14:conj	_
# 18	más	más	ADV	rg	Degree=Cmp	17	obj	17:obj	SpaceAfter=No
# 19	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	SpaceAfter=No
# 20	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 21	subrayó	subrayar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	SpaceAfter=No
# 21.1	_	_	PRON	p	_	_	_	21:nsubj	ClusterId=CESS-CAST-AA-20000923-19559-c1|ClusterType=Spec.person|MentionSpan=21.1|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 22	.	.	PUNCT	fp	PunctType=Peri	21	punct	21:punct	_
#
#
# # newdoc id = CESS-CAST-AA-20000927-23199
# # sent_id = CESS-CAST-AA-20000927-23199-s1
# # text = El jugador del equipo de Primera División de fútbol de la UD Las Palmas, Francisco Ortíz "Paquito", calificó hoy de "lamentable" la pelea que ayer protagonizaron sus compañeros Vincent Samways (inglés) y Oktay Derelioglu (turco) en un entrenamiento.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	_
# 2	jugador	jugador	NOUN	ncms000	Gender=Masc|Number=Sing	23	nsubj	23:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c1|ClusterType=Spec.person|MentionSpan=1-22
# 3-4	del	_	_	_	_	_	_	_	_
# 3	de	de	ADP	spcms	_	5	case	5:case	_
# 4	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	_
# 5	equipo	equipo	NOUN	ncms000	Gender=Masc|Number=Sing	2	nmod	2:nmod	ClusterId=CESS-CAST-AA-20000927-23199-c3|ClusterType=Spec.organization|MentionSpan=5-15
# 6	de	de	ADP	sps00	_	7	case	7:case	_
# 7	Primera	Primera	PROPN	np00000	_	5	nmod	5:nmod	MWE=Primera_División|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000927-23199-s1.sn.16|ClusterType=Spec.other|MentionSpan=7-8
# 8	División	División	PROPN	_	_	7	flat	7:flat	_
# 9	de	de	ADP	sps00	_	10	case	10:case	_
# 10	fútbol	fútbol	NOUN	ncms000	Gender=Masc|Number=Sing	5	nmod	5:nmod	_
# 11	de	de	ADP	sps00	_	13	case	13:case	_
# 12	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	13	det	13:det	_
# 13	UD	UD	PROPN	np00000	_	5	nmod	5:nmod	MWE=UD_Las_Palmas|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000927-23199-c6|ClusterType=Spec.organization|MentionSpan=12-15
# 14	Las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	15	det	15:det	_
# 15	Palmas	Palmas	PROPN	_	_	13	flat	13:flat	SpaceAfter=No
# 16	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	_
# 17	Francisco	Francisco	PROPN	np00000	_	2	appos	2:appos	MWE=Francisco_Ortíz|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000927-23199-c1|ClusterType=Spec.person|MentionSpan=16-22|MentionMisc=CorefType:pred.definit
# 18	Ortíz	Ortíz	PROPN	_	_	17	flat	17:flat	_
# 19	"	"	PUNCT	fe	PunctType=Quot	20	punct	20:punct	SpaceAfter=No
# 20	Paquito	Paquito	PROPN	np00000	_	17	flat	17:flat	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000927-23199-s1.sn.37|ClusterType=Spec.person|MentionSpan=19-21
# 21	"	"	PUNCT	fe	PunctType=Quot	20	punct	20:punct	SpaceAfter=No
# 22	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	_
# 23	calificó	calificar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 24	hoy	hoy	ADV	rg	_	23	advmod	23:advmod	_
# 25	de	de	ADP	sps00	_	27	case	27:case	_
# 26	"	"	PUNCT	fe	PunctType=Quot	27	punct	27:punct	SpaceAfter=No
# 27	lamentable	lamentable	ADJ	aq0cs0	Number=Sing	23	obj	23:obj	SpaceAfter=No
# 28	"	"	PUNCT	fe	PunctType=Quot	27	punct	27:punct	_
# 29	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	30	det	30:det	_
# 30	pelea	pelea	NOUN	ncfs000	Gender=Fem|Number=Sing	23	obj	23:obj	ClusterId=CESS-CAST-AA-20000927-23199-c2|ClusterType=Gen|MentionSpan=29-49|MentionMisc=HomoDD
# 31	que	que	PRON	pr0cn000	PronType=Int,Rel	33	obj	33:obj	ClusterId=CESS-CAST-AA-20000927-23199-c2|ClusterType=Gen|MentionSpan=31|MentionMisc=CorefType:ident
# 32	ayer	ayer	ADV	rg	_	33	advmod	33:advmod	_
# 33	protagonizaron	protagonizar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	30	acl	30:acl	_
# 34	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	35	det	35:det	ClusterId=CESS-CAST-AA-20000927-23199-c1|ClusterType=Spec.person|MentionSpan=34|MentionMisc=ClusterTypeMismatch:Spec:Spec.person,CorefType:ident
# 35	compañeros	compañero	NOUN	ncmp000	Gender=Masc|Number=Plur	33	nsubj	33:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c5|ClusterType=Gen|MentionSpan=34-46
# 36	Vincent	Vincent	PROPN	np00000	_	35	appos	35:appos	MWE=Vincent_Samways|MWEPOS=PROPN
# 37	Samways	Samways	PROPN	_	_	36	flat	36:flat	_
# 38	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	39	punct	39:punct	SpaceAfter=No
# 39	inglés	inglés	ADJ	aq0ms0	Gender=Masc|Number=Sing	36	amod	36:amod	SpaceAfter=No
# 40	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	39	punct	39:punct	_
# 41	y	y	CCONJ	cc	_	42	cc	42:cc	_
# 42	Oktay	Oktay	PROPN	np00000	_	36	conj	36:conj	MWE=Oktay_Derelioglu|MWEPOS=PROPN
# 43	Derelioglu	Derelioglu	PROPN	_	_	42	flat	42:flat	_
# 44	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	45	punct	45:punct	SpaceAfter=No
# 45	turco	turco	ADJ	aq0ms0	Gender=Masc|Number=Sing	42	amod	42:amod	SpaceAfter=No
# 46	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	45	punct	45:punct	_
# 47	en	en	ADP	sps00	_	49	case	49:case	_
# 48	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	49	det	49:det	_
# 49	entrenamiento	entrenamiento	NOUN	ncms000	Gender=Masc|Number=Sing	33	obl	33:obl	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000927-23199-s1.sn.96|ClusterType=Gen|MentionSpan=48-49
# 50	.	.	PUNCT	fp	PunctType=Peri	23	punct	23:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000927-23199-s2
# # text = Paquito manifestó que este tipo de hechos afecta al resto de compañeros y "no beneficia al equipo", al margen de la negativa imagen exterior que puede crearse de la entidad UD Las Palmas SAD.
# 1	Paquito	Paquito	PROPN	np00000	_	2	nsubj	2:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c1|ClusterType=Spec.person|MentionSpan=1|MentionMisc=CorefType:ident
# 2	manifestó	manifestar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 3	que	que	SCONJ	cs	_	8	mark	8:mark	_
# 4	este	este	DET	dd0ms0	Gender=Masc|Number=Sing|PronType=Dem	5	det	5:det	_
# 5	tipo	tipo	NOUN	ncms000	Gender=Masc|Number=Sing	8	nsubj	8:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c2|ClusterType=Gen|MentionSpan=4-7|MentionMisc=CorefType:ident
# 6	de	de	ADP	sps00	_	7	case	7:case	_
# 7	hechos	hecho	NOUN	ncmp000	Gender=Masc|Number=Plur	5	nmod	5:nmod	_
# 8	afecta	afectar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	2	ccomp	2:ccomp	_
# 9-10	al	_	_	_	_	_	_	_	_
# 9	a	a	ADP	spcms	_	11	case	11:case	_
# 10	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	11	det	11:det	_
# 11	resto	resto	NOUN	ncms000	Gender=Masc|Number=Sing	8	obj	8:obj	ClusterId=CESS-CAST-AA-20000927-23199-s2.sn.27|ClusterType=Gen|MentionSpan=11-13
# 12	de	de	ADP	sps00	_	13	case	13:case	_
# 13	compañeros	compañero	NOUN	ncmp000	Gender=Masc|Number=Plur	11	nmod	11:nmod	_
# 14	y	y	CCONJ	cc	_	17	cc	17:cc	_
# 15	"	"	PUNCT	fe	PunctType=Quot	17	punct	17:punct	SpaceAfter=No
# 15.1	_	_	PRON	p	_	_	_	17:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c2|ClusterType=Gen|MentionSpan=15.1|MentionMisc=CorefType:ident
# 16	no	no	ADV	rn	Polarity=Neg	17	advmod	17:advmod	_
# 17	beneficia	beneficiar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	8	conj	8:conj	_
# 18-19	al	_	_	_	_	_	_	_	_
# 18	a	a	ADP	spcms	_	20	case	20:case	_
# 19	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	_
# 20	equipo	equipo	NOUN	ncms000	Gender=Masc|Number=Sing	17	obj	17:obj	SpaceAfter=No|ClusterId=CESS-CAST-AA-20000927-23199-c3|ClusterType=Spec.organization|MentionSpan=20|MentionMisc=ClusterTypeMismatch:Spec:Spec.organization,CorefType:ident
# 21	"	"	PUNCT	fe	PunctType=Quot	17	punct	17:punct	SpaceAfter=No
# 22	,	,	PUNCT	fc	PunctType=Comm	29	punct	29:punct	_
# 23-24	al	_	_	_	_	_	_	_	MWE=al_margen_de|MWEPOS=ADP
# 23	a	a	ADP	sps00	_	29	case	29:case	MWE=al_margen_de|MWEPOS=ADP
# 24	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	29:det	_
# 25	margen	margen	NOUN	_	_	23	fixed	23:fixed	_
# 26	de	de	ADP	_	_	23	fixed	23:fixed	_
# 27	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	29:det	_
# 28	negativa	negativo	ADJ	aq0fs0	Gender=Fem|Number=Sing	29	amod	29:amod	_
# 29	imagen	imagen	NOUN	ncfs000	Gender=Fem|Number=Sing	17	obl	17:obl	ClusterId=CESS-CAST-AA-20000927-23199-c4|ClusterType=Gen|MentionSpan=27-41|MentionMisc=HomoDD
# 30	exterior	exterior	ADJ	aq0cs0	Number=Sing	29	amod	29:amod	_
# 31	que	que	PRON	pr0cn000	PronType=Int,Rel	33	nsubj	33:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c4|ClusterType=Gen|MentionSpan=31|MentionMisc=CorefType:ident
# 32	puede	poder	AUX	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	33	aux	33:aux	_
# 33-34	crearse	_	_	_	_	_	_	_	_
# 33	crear	crear	VERB	vmn0000	VerbForm=Inf	29	acl	29:acl	_
# 34	se	él	PRON	_	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	33	expl:pass	33:expl:pass	_
# 35	de	de	ADP	sps00	_	37	case	37:case	_
# 36	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	37	det	37:det	_
# 37	entidad	entidad	NOUN	ncfs000	Gender=Fem|Number=Sing	29	nmod	29:nmod	ClusterId=CESS-CAST-AA-20000927-23199-c6|ClusterType=Spec.organization|MentionSpan=36-41|MentionMisc=CorefType:ident
# 38	UD	UD	PROPN	np00000	_	37	appos	37:appos	MWE=UD_Las_Palmas_SAD|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000927-23199-s2.sn.82|ClusterType=Spec.organization|MentionSpan=38-41
# 39	Las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	40	det	40:det	_
# 40	Palmas	Palmas	PROPN	_	_	38	flat	38:flat	_
# 41	SAD	SAD	PROPN	_	_	40	flat	40:flat	SpaceAfter=No
# 42	.	.	PUNCT	fp	PunctType=Peri	2	punct	2:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000927-23199-s3
# # text = Tanto Samways como Oktay han sido expedientados por los dirigentes de la UD Las Palmas y se entrenarán aparte, de momento, hasta el día 3 de octubre.
# 1	Tanto	tanto	ADV	rg	_	2	cc	2:cc	_
# 2	Samways	Samways	PROPN	np00000	_	7	nsubj	7:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c5|ClusterType=Gen|MentionSpan=1-4|MentionMisc=CorefType:ident
# 3	como	como	SCONJ	cs	_	4	cc	4:cc	_
# 4	Oktay	Oktay	PROPN	np00000	_	2	conj	2:conj	_
# 5	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	7	aux	7:aux	_
# 6	sido	ser	AUX	vsp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	7	aux	7:aux	_
# 7	expedientados	expedientar	VERB	vmp00pm	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	0	root	0:root	_
# 8	por	por	ADP	sps00	_	10	case	10:case	_
# 9	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	10	det	10:det	_
# 10	dirigentes	dirigente	NOUN	nccp000	Number=Plur	7	obj	7:obj	ClusterId=CESS-CAST-AA-20000927-23199-s3.sn.20|ClusterType=Gen|MentionSpan=9-15|MentionMisc=HomoDD
# 11	de	de	ADP	sps00	_	13	case	13:case	_
# 12	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	13	det	13:det	_
# 13	UD	UD	PROPN	np00000	_	10	nmod	10:nmod	MWE=UD_Las_Palmas|MWEPOS=PROPN|ClusterId=CESS-CAST-AA-20000927-23199-c6|ClusterType=Spec.organization|MentionSpan=12-15|MentionMisc=CorefType:ident
# 14	Las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	15	det	15:det	_
# 15	Palmas	Palmas	PROPN	_	_	13	flat	13:flat	_
# 16	y	y	CCONJ	cc	_	18	cc	18:cc	_
# 16.1	_	_	PRON	p	_	_	_	18:nsubj	ClusterId=CESS-CAST-AA-20000927-23199-c5|ClusterType=Gen|MentionSpan=16.1|MentionMisc=CorefType:ident
# 17	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	18	expl:pv	18:expl:pv	_
# 18	entrenarán	entrenar	VERB	vmif3p0	Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin	7	conj	7:conj	_
# 19	aparte	aparte	ADV	rg	_	18	advmod	18:advmod	SpaceAfter=No
# 20	,	,	PUNCT	fc	PunctType=Comm	21	punct	21:punct	_
# 21	de	de	ADP	rg	_	18	advmod	18:advmod	MWE=de_momento|MWEPOS=ADV
# 22	momento	momento	NOUN	_	_	21	fixed	21:fixed	SpaceAfter=No
# 23	,	,	PUNCT	fc	PunctType=Comm	21	punct	21:punct	_
# 24	hasta	hasta	ADP	sps00	_	26	case	26:case	_
# 25	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	26:det	_
# 26	día	día	NOUN	_	_	18	obl	18:obl	MWE=día_3_de_octubre|MWEPOS=NOUN|ClusterId=CESS-CAST-AA-20000927-23199-s3.sn.52|ClusterType=Spec.date|MentionSpan=25-29
# 27	3	3	NUM	_	NumForm=Digit|NumType=Card	26	compound	26:compound	_
# 28	de	de	ADP	_	_	29	case	29:case	_
# 29	octubre	octubre	NOUN	_	_	26	compound	26:compound	SpaceAfter=No
# 30	.	.	PUNCT	fp	PunctType=Peri	7	punct	7:punct	_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#@title Estructura de los tokens etiquetados del corpus
tokenlist[1]
# Out:
# {'deprel': 'det',
#  'deps': [('det', 5)],
#  'feats': {'Definite': 'Def',
#   'Gender': 'Masc',
#   'Number': 'Sing',
#   'PronType': 'Art'},
#  'form': 'El',
#  'head': 5,
#  'id': 2,
#  'lemma': 'el',
#  'misc': None,
#  'upos': 'DET',
#  'xpos': 'da0ms0'}

# %%
tokenlist[1]['form']+'|'+tokenlist[1]['upos']
# Out:
# 'El|DET'

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {} 
emissionDict = {}
transitionDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file):
  prevtag = None
  for token in tokenlist:

    # C(tag)
    tag = token[tagtype]
    if tag in tagCountDict.keys():
      tagCountDict[tag] += 1
    else:
      tagCountDict[tag] = 1

    # C(word|tag) -> probabilidades emision
    wordtag = token['form'].lower()+'|'+token[tagtype] # (word|tag)
    if wordtag in emissionDict.keys():
      emissionDict[wordtag] = emissionDict[wordtag] + 1
    else:
      emissionDict[wordtag] = 1

    #  C(tag|tag_previo) -> probabilidades transición
    if prevtag is None:
      prevtag = tag
      continue
    transitiontags = tag+'|'+prevtag
    if transitiontags in transitionDict.keys():
      transitionDict[transitiontags] = transitionDict[transitiontags] + 1
    else:
      transitionDict[transitiontags] = 1
    prevtag = tag
    
#transitionDict
#emissionDict
#tagCountDict

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
# * probabilidades de transición:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * probabilidades de emisión:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {} # matriz A
emissionProbDict = {} # matriz B

# transition Probabilities 
for key in transitionDict.keys():
  tag, prevtag = key.split('|')
  if tagCountDict[prevtag]>0:
    transitionProbDict[key] = transitionDict[key]/(tagCountDict[prevtag])
  else:
    print(key)

# emission Probabilities 
for key in emissionDict.keys():
  word, tag = key.split('|')
  if emissionDict[key]>0:
    emissionProbDict[key] = emissionDict[key]/tagCountDict[tag]
  else:
    print(key)

transitionProbDict['ADJ|ADJ']
#emissionProbDict
# Out:
# 0.030225988700564973

# %% [markdown]
# ## Guardar parámetros del modelo

# %%
import numpy as np
np.save('transitionHMM.npy', transitionProbDict)
np.save('emissionHMM.npy', emissionProbDict)
transitionProbdict = np.load('transitionHMM.npy', allow_pickle='TRUE').item()
transitionProbDict['ADJ|ADJ']
# Out:
# 0.030225988700564973
